# %% [markdown]
# # logs_local_berk Leaderboard
#
# Compare all runs from `logs_local_berk` (AI-GUIDED-CLEAN patch-based trainings on ROSIE TCGA): EarlyFusion, FiLM Rosie, FiLM ImageNet, etc.

# %%
import sys
from pathlib import Path

import pandas as pd

# Show full run names in tables (no truncation) - same as 00_global_leaderboard
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_rows", None)

PROJECT_ROOT = Path("/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis")
LOGS_LOCAL_BERK = PROJECT_ROOT / "AI-GUIDED-CLEAN/ProcessedDataset/v1_40x_area20_2/patches_cellvit_p256/trainings_idinit"

sys.path.insert(0, str(PROJECT_ROOT / "Datasets/pannuke_hf_cellvit/notebooks"))
from notebook_utils import load_runs_dataframe

# %%
runs_df = load_runs_dataframe(LOGS_LOCAL_BERK)
print(f"Loaded {len(runs_df)} runs")
# Out:
# Loaded 14 runs

# %% [markdown]
# ## A) Overall Leaderboard (top 15 by mPQ)

# %%
lb = runs_df.sort_values("mPQ", ascending=False).head(15)
cols = ["run_name", "backbone", "method", "condition_source", "film_target", "mPQ", "bPQ", "DQ", "SQ", "Dice", "Jaccard", "F1"]
lb[[c for c in cols if c in lb.columns]]
# Out:
#                                                                            run_name  \
# 12  2026-02-23T082633_VirchowRosieFiLM-z4-betaonly-idinit-lr3e5-filmlr1-TCGA-seed19
# 10                   2026-02-23T082515_Virchow TrueBaseline TCGA seed19 lr3e-5 bs16
# 1                  2026-02-23T014746_VirchowRosie-baseline-TCGA-idinit-lr3e5-seed19
# 9            2026-02-23T082424_VirchowRosieFiLM-z4-idinit-lr3e5-filmlr1-TCGA-seed19
# 13     2026-02-23T104505_SAMHRosieFiLM-z4-betaonly-idinit-lr3e5-filmlr1-TCGA-seed19
# 8            2026-02-23T082422_Virchow FiLMIdentityTrain z4 TCGA seed19 lr3e-5 bs16
# 11           2026-02-23T082515_VirchowRosieFiLM-z4-idinit-lr3e5-filmlr3-TCGA-seed19
# 2                    2026-02-23T014746_VirchowRosieFiLM-z4-idinit-lr3e5-TCGA-seed19
# 4                  2026-02-23T032358_VirchowRosieFiLM-z1z4-idinit-lr3e5-TCGA-seed19
# 3                  2026-02-23T031117_VirchowRosieFiLM-z3z4-idinit-lr3e5-TCGA-seed19
# 0                     2026-02-23T014746_SAMHRosie-baseline-TCGA-idinit-lr3e5-seed19
# 5                       2026-02-23T033732_SAMHRosieFiLM-z4-idinit-lr3e5-TCGA-seed19
# 7                     2026-02-23T042530_SAMHRosieFiLM-z1z4-idinit-lr3e5-TCGA-seed19
# 6                     2026-02-23T042522_SAMHRosieFiLM-z3z4-idinit-lr3e5-TCGA-seed19
#
#    backbone    method condition_source  film_target       mPQ       bPQ  \
# 12  Virchow      FiLM            Rosie           z4  0.569725  0.651865
# 10  Virchow  Baseline             None         None  0.562943  0.645599
# 1   Virchow  Baseline            Rosie         None  0.558948  0.646448
# 9   Virchow      FiLM            Rosie           z4  0.554059  0.647099
# 13    SAM-H      FiLM            Rosie           z4  0.544679  0.619973
# 8   Virchow      FiLM            Rosie           z4  0.544426  0.623917
# 11  Virchow      FiLM            Rosie           z4  0.543591  0.624743
# 2   Virchow      FiLM            Rosie           z4  0.540325  0.618014
# 4   Virchow      FiLM            Rosie  z1,z2,z3,z4  0.540109  0.633111
# 3   Virchow      FiLM            Rosie        z3,z4  0.537684  0.629221
# 0     SAM-H  Baseline            Rosie         None  0.535426  0.617686
# 5     SAM-H      FiLM            Rosie           z4  0.533872  0.625211
# 7     SAM-H      FiLM            Rosie  z1,z2,z3,z4  0.529073  0.612473
# 6     SAM-H      FiLM            Rosie        z3,z4  0.524766  0.619788
#
#           DQ        SQ
# 12  0.697948  0.704182
# 10  0.693139  0.702650
# 1   0.688151  0.691255
# 9   0.679589  0.685347
# 13  0.683237  0.701579
# 8   0.672502  0.673189
# 11  0.670024  0.677452
# 2   0.667072  0.679605
# 4   0.662523  0.677244
# 3   0.665642  0.680534
# 0   0.663031  0.691724
# 5   0.660125  0.680738
# 7   0.669489  0.671109
# 6   0.656816  0.668164

# %% [markdown]
# ## B) Best per Group

# %%
grp = ["backbone", "method", "condition_source", "film_target"]
grp = [c for c in grp if c in runs_df.columns]
best_per = runs_df.loc[runs_df.groupby(grp)["mPQ"].idxmax()]
best_per = best_per.sort_values("mPQ", ascending=False)
best_per[[c for c in ["run_name"] + grp + ["mPQ", "bPQ", "DQ", "SQ", "Dice", "Jaccard", "F1"] if c in best_per.columns]].head(20)
# Out:
#                                                                            run_name  \
# 12  2026-02-23T082633_VirchowRosieFiLM-z4-betaonly-idinit-lr3e5-filmlr1-TCGA-seed19
# 10                   2026-02-23T082515_Virchow TrueBaseline TCGA seed19 lr3e-5 bs16
# 1                  2026-02-23T014746_VirchowRosie-baseline-TCGA-idinit-lr3e5-seed19
# 13     2026-02-23T104505_SAMHRosieFiLM-z4-betaonly-idinit-lr3e5-filmlr1-TCGA-seed19
# 4                  2026-02-23T032358_VirchowRosieFiLM-z1z4-idinit-lr3e5-TCGA-seed19
# 3                  2026-02-23T031117_VirchowRosieFiLM-z3z4-idinit-lr3e5-TCGA-seed19
# 0                     2026-02-23T014746_SAMHRosie-baseline-TCGA-idinit-lr3e5-seed19
# 7                     2026-02-23T042530_SAMHRosieFiLM-z1z4-idinit-lr3e5-TCGA-seed19
# 6                     2026-02-23T042522_SAMHRosieFiLM-z3z4-idinit-lr3e5-TCGA-seed19
#
#    backbone    method condition_source  film_target       mPQ
# 12  Virchow      FiLM            Rosie           z4  0.569725
# 10  Virchow  Baseline             None         None  0.562943
# 1   Virchow  Baseline            Rosie         None  0.558948
# 13    SAM-H      FiLM            Rosie           z4  0.544679
# 4   Virchow      FiLM            Rosie  z1,z2,z3,z4  0.540109
# 3   Virchow      FiLM            Rosie        z3,z4  0.537684
# 0     SAM-H  Baseline            Rosie         None  0.535426
# 7     SAM-H      FiLM            Rosie  z1,z2,z3,z4  0.529073
# 6     SAM-H      FiLM            Rosie        z3,z4  0.524766

# %% [markdown]
# ## C) Method Comparison: EarlyFusion vs FiLM vs Baseline

# %%
# Best run per method (table format, like 00_global_leaderboard)
method_best = runs_df.loc[runs_df.groupby("method")["mPQ"].idxmax()]
method_best = method_best.sort_values("mPQ", ascending=False)
cols = ["run_name", "backbone", "method", "condition_source", "film_target", "mPQ", "bPQ", "DQ", "SQ", "Dice", "Jaccard", "F1"]
method_best[[c for c in cols if c in method_best.columns]]
# Out:
#                                                                            run_name  \
# 12  2026-02-23T082633_VirchowRosieFiLM-z4-betaonly-idinit-lr3e5-filmlr1-TCGA-seed19
# 10                   2026-02-23T082515_Virchow TrueBaseline TCGA seed19 lr3e-5 bs16
#
#    backbone    method condition_source film_target       mPQ       bPQ  \
# 12  Virchow      FiLM            Rosie          z4  0.569725  0.651865
# 10  Virchow  Baseline             None        None  0.562943  0.645599
#
#           DQ        SQ
# 12  0.697948  0.704182
# 10  0.693139  0.702650

# %% [markdown]
# ## D) Apples-to-Apples: FiLM vs Baseline (by backbone)

# %%
baselines = runs_df[runs_df["method"] == "Baseline"].copy()
films = runs_df[runs_df["method"].isin(["FiLM", "ProxyFiLM", "LoRA+FiLM"])].copy()

rows = []
for bb in runs_df["backbone"].dropna().unique():
    base = baselines[baselines["backbone"] == bb]
    film = films[films["backbone"] == bb]
    if base.empty or film.empty:
        continue
    best_base = base.loc[base["mPQ"].idxmax()]
    best_film = film.loc[film["mPQ"].idxmax()]
    delta = best_film["mPQ"] - best_base["mPQ"]
    rows.append({
        "backbone": bb,
        "baseline_run": best_base["run_name"],
        "baseline_mPQ": best_base["mPQ"],
        "best_film_run": best_film["run_name"],
        "film_mPQ": best_film["mPQ"],
        "delta_mPQ": delta,
    })

if rows:
    delta_df = pd.DataFrame(rows).sort_values("delta_mPQ", ascending=False)
    delta_df
else:
    print("No backbone groups with both Baseline and FiLM runs.")

# %% [markdown]
# ## E) Narrative Summary

# %%
best_run = runs_df.loc[runs_df["mPQ"].idxmax()]
print("Best overall run:", best_run["run_name"])
print("  mPQ =", round(best_run["mPQ"], 4))
print()

if rows:
    for _, r in delta_df.iterrows():
        print(f"Backbone {r['backbone']}:")
        print(f"  Baseline mPQ = {r['baseline_mPQ']:.4f}")
        print(f"  Best FiLM mPQ = {r['film_mPQ']:.4f}")
        print(f"  Delta = {r['delta_mPQ']:+.4f}")
        print()
    pos = (delta_df["delta_mPQ"] > 0).sum()
    tot = len(delta_df)
    print(f"FiLM helps in {pos}/{tot} backbones.")
    if pos == tot:
        print("-> FiLM helps consistently across all backbones.")
    elif pos > 0:
        print("-> FiLM helps only in certain backbones/targets.")
    else:
        print("-> FiLM does not improve over baseline.")
# Out:
# Best overall run: 2026-02-23T082633_VirchowRosieFiLM-z4-betaonly-idinit-lr3e5-filmlr1-TCGA-seed19
#   mPQ = 0.5697
#
# Backbone SAM-H:
#   Baseline mPQ = 0.5354
#   Best FiLM mPQ = 0.5447
#   Delta = +0.0093
#
# Backbone Virchow:
#   Baseline mPQ = 0.5629
#   Best FiLM mPQ = 0.5697
#   Delta = +0.0068
#
# FiLM helps in 2/2 backbones.
# -> FiLM helps consistently across all backbones.
