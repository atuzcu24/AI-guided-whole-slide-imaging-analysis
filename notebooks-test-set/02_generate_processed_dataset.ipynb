# %% [markdown]
# # Dataset Processing — Step 2: Generate Structured Dataset
#
# **Goal:**
# This notebook converts raw `.svs` / `.tif` + `.xml` data into a clean, versioned, and patch-based dataset.
# Outputs are organized under `ProcessedDataset/v1_40x_area20/` and include:
# - `whole_slide/` → full-resolution type and instance maps
# - `patches_p512/` → cropped 512×512 image/label pairs
# - `_meta/` → class map + parameters
# - `logs/` → run summaries
#
# ---
#
# ### Steps
# 1. Configure paths and parameters
# 2. Create folder structure
# 3. Discover `.svs` / `.xml` pairs
# 4. Parse polygons → generate `inst_map` & `type_map`
# 5. Extract and save 512×512 patches
#
# ---
#
# ### Table of Contents
# - [Step 1 — Setup and Folder Creation](#step1)
# - [Step 2 — Pair .svs/.xml Files](#step2)
# - [Step 3 — XML Parsing Functions](#step3)
# - [Step 4 — Patch Generation](#step4)

# %% [markdown]
# <a id="step1"></a>
# ## Step 1 — Setup and Folder Creation

# %%
from pathlib import Path
import json, os
from datetime import datetime
from xml.dom import minidom

# === Configuration ===
PATCH_SIZE = 512
MIN_POLY_AREA = 20

TEST_DIR = Path("/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/TestDataTCGA/TestingData/TestingData")


RAW_ROOT = TEST_DIR

OUT_ROOT = Path(
    f"/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/ProcessedDataset/v1_40x_area{MIN_POLY_AREA}_3"
)

# === Create folder structure ===
dirs = [
    OUT_ROOT / "whole_slide" / "type_maps",
    OUT_ROOT / "whole_slide" / "inst_maps",
    OUT_ROOT / "whole_slide" / "debug",
    OUT_ROOT / f"patches_p{PATCH_SIZE}" / "images",
    OUT_ROOT / f"patches_p{PATCH_SIZE}" / "labels",
    OUT_ROOT / f"patches_p{PATCH_SIZE}" / "debug",
    OUT_ROOT / "_meta",
    OUT_ROOT / "logs",
]
for d in dirs:
    d.mkdir(parents=True, exist_ok=True)

print(f"✅ Folder structure initialized at: {OUT_ROOT}")

# === Save processing parameters ===
meta_info = {
    "created_at": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
    "PATCH_SIZE": PATCH_SIZE,
    "MIN_POLY_AREA": MIN_POLY_AREA,
    "description": "Processed dataset generated from raw histopathology slides at 40x magnification."
}
with open(OUT_ROOT / "_meta" / "params.json", "w") as f:
    json.dump(meta_info, f, indent=2)
print("Saved params.json")

# === Dynamically extract class map from XML annotations ===
def extract_class_map_from_xmls(root_dir: Path, max_files=50):
    """Scan XML annotations and collect all unique cell-type labels."""
    labels = set()
    xml_files = list(root_dir.glob("**/*.xml"))[:max_files]
    for xml_path in xml_files:
        xmldoc = minidom.parse(str(xml_path))
        for ann in xmldoc.getElementsByTagName("Annotation"):
            for attr in ann.getElementsByTagName("Attribute"):
                if attr.hasAttribute("Name"):
                    labels.add(attr.getAttribute("Name").strip().lower())
    return sorted(labels)

found_labels = [lbl for lbl in extract_class_map_from_xmls(RAW_ROOT, max_files=50)
                if not lbl.isdigit() and len(lbl) > 1]
print(f"✅ Detected {len(found_labels)} valid labels:", found_labels)


# Assign numeric IDs (background = 0)
class_map = {"0": "background"}
for i, label in enumerate(found_labels, start=1):
    class_map[str(i)] = label

with open(OUT_ROOT / "_meta" / "class_map.json", "w") as f:
    json.dump(class_map, f, indent=2)

print(f"Saved class_map.json with {len(class_map)-1} classes (plus background)")

# === Optional: log summary to file ===
log_path = OUT_ROOT / "logs" / "setup.log"
with open(log_path, "w") as f:
    f.write(f"Setup completed at {meta_info['created_at']}\n")
    f.write(f"Output root: {OUT_ROOT}\n")
    f.write(f"Detected labels: {found_labels}\n")

print(f"Log written → {log_path}")
# Out:
# ✅ Folder structure initialized at: /projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/ProcessedDataset/v1_40x_area20_3
# Saved params.json
# ✅ Detected 5 valid labels: ['ambiguous', 'epithelial', 'lymphocyte', 'macrophage', 'neutrophil']
# Saved class_map.json with 5 classes (plus background)
# Log written → /projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/ProcessedDataset/v1_40x_area20_3/logs/setup.log

# %% [markdown]
# <a id="step2"></a>
# ## Step 2 — Pair .svs and .xml files

# %%
import pandas as pd

def discover_svs_xml_pairs(root_dir: Path):
    """
    Walk through the dataset and pair each .svs slide with its .xml annotation.
    Returns a DataFrame with columns: patient, image_name, svs_path, xml_path.
    """
    records = []
    patients = sorted([d for d in root_dir.iterdir() if d.is_dir()])
    print(f"Scanning {len(patients)} patient folders under {root_dir.name}")

    for patient_path in patients:
        patient_id = patient_path.name
        svs_files = sorted(patient_path.glob("*.svs"))

        for svs_path in svs_files:
            name = svs_path.stem
            xml_path = patient_path / f"{name}.xml"
            has_xml = xml_path.exists()
            records.append({
                "patient": patient_id,
                "image_name": name,
                "svs_path": svs_path,
                "xml_path": xml_path if has_xml else None,
                "has_xml": has_xml,
            })

    df = pd.DataFrame(records)
    return df


pairs_df = discover_svs_xml_pairs(RAW_ROOT)
print(f"✅ Total slides found: {len(pairs_df)}")
print(f"✅ Slides with matching XML: {pairs_df['has_xml'].sum()}")

# Show missing annotations, if any
missing = pairs_df[~pairs_df["has_xml"]]
if not missing.empty:
    print("\nSlides missing XML annotations:")
    display(missing[["patient", "image_name"]])
else:
    print("✅ All slides have XML annotations")

# Preview a few pairs
display(pairs_df.head())
# Out:
# Scanning 9 patient folders under TestingData
# ✅ Total slides found: 31
# ✅ Slides with matching XML: 2
#
# Slides missing XML annotations:
#                     patient                   image_name
# 0   TCGA-55-7570-01Z-00-DX1  TCGA-55-7570-01Z-00-DX1_001
# 1   TCGA-55-7570-01Z-00-DX1  TCGA-55-7570-01Z-00-DX1_002
# 4   TCGA-A2-A04X-01Z-00-DX1  TCGA-A2-A04X-01Z-00-DX1_001
# 5   TCGA-A2-A04X-01Z-00-DX1  TCGA-A2-A04X-01Z-00-DX1_002
# 6   TCGA-A2-A04X-01Z-00-DX1  TCGA-A2-A04X-01Z-00-DX1_003
# 7   TCGA-A2-A04X-01Z-00-DX1  TCGA-A2-A04X-01Z-00-DX1_004
# 8   TCGA-A2-A0ES-01Z-00-DX1  TCGA-A2-A0ES-01Z-00-DX1_001
# 9   TCGA-A2-A0ES-01Z-00-DX1  TCGA-A2-A0ES-01Z-00-DX1_002
# 10  TCGA-A2-A0ES-01Z-00-DX1  TCGA-A2-A0ES-01Z-00-DX1_003
# 11  TCGA-A2-A0ES-01Z-00-DX1  TCGA-A2-A0ES-01Z-00-DX1_004
# 12  TCGA-DW-7838-01Z-00-DX1    TCGA-DW-7838-01Z-00-DX1_1
# 13  TCGA-DW-7838-01Z-00-DX1    TCGA-DW-7838-01Z-00-DX1_2
# 14  TCGA-DW-7838-01Z-00-DX1    TCGA-DW-7838-01Z-00-DX1_3
# 15  TCGA-DW-7838-01Z-00-DX1    TCGA-DW-7838-01Z-00-DX1_4
# 16  TCGA-DW-7838-01Z-00-DX1    TCGA-DW-7838-01Z-00-DX1_5
# 17  TCGA-F9-A8NY-01Z-00-DX1    TCGA-F9-A8NY-01Z-00-DX1_1
# 18  TCGA-F9-A8NY-01Z-00-DX1    TCGA-F9-A8NY-01Z-00-DX1_2
# 19  TCGA-F9-A8NY-01Z-00-DX1    TCGA-F9-A8NY-01Z-00-DX1_3
# 20  TCGA-F9-A8NY-01Z-00-DX1    TCGA-F9-A8NY-01Z-00-DX1_4
# 21  TCGA-VP-A87E-01Z-00-DX1    TCGA-VP-A87E-01Z-00-DX1_1
# 22  TCGA-VP-A87E-01Z-00-DX1    TCGA-VP-A87E-01Z-00-DX1_2
# 23  TCGA-VP-A87E-01Z-00-DX1    TCGA-VP-A87E-01Z-00-DX1_3
# 24  TCGA-VP-A87E-01Z-00-DX1    TCGA-VP-A87E-01Z-00-DX1_4
# 25  TCGA-VP-A87E-01Z-00-DX1    TCGA-VP-A87E-01Z-00-DX1_5
# 26  TCGA-X4-A8KS-01Z-00-DX3    TCGA-X4-A8KS-01Z-00-DX3_1
# 27  TCGA-YL-A9WL-01Z-00-DX1    TCGA-YL-A9WL-01Z-00-DX1_1
# 28  TCGA-YL-A9WL-01Z-00-DX1    TCGA-YL-A9WL-01Z-00-DX1_2
# 29  TCGA-YL-A9WL-01Z-00-DX1    TCGA-YL-A9WL-01Z-00-DX1_3
# 30  TCGA-YL-A9WL-01Z-00-DX1    TCGA-YL-A9WL-01Z-00-DX1_4
#                    patient                   image_name  \
# 0  TCGA-55-7570-01Z-00-DX1  TCGA-55-7570-01Z-00-DX1_001
# 1  TCGA-55-7570-01Z-00-DX1  TCGA-55-7570-01Z-00-DX1_002
# 2  TCGA-78-7152-01Z-00-DX1  TCGA-78-7152-01Z-00-DX1_001
# 3  TCGA-78-7152-01Z-00-DX1  TCGA-78-7152-01Z-00-DX1_002
# 4  TCGA-A2-A04X-01Z-00-DX1  TCGA-A2-A04X-01Z-00-DX1_001
#
#                                             svs_path  \
# 0  /projectnb/ec500kb/projects/Fall_2025_Projects...
# 1  /projectnb/ec500kb/projects/Fall_2025_Projects...
# 2  /projectnb/ec500kb/projects/Fall_2025_Projects...
# 3  /projectnb/ec500kb/projects/Fall_2025_Projects...
# 4  /projectnb/ec500kb/projects/Fall_2025_Projects...
#
#                                             xml_path  has_xml
# 0                                               None    False
# 1                                               None    False
# 2  /projectnb/ec500kb/projects/Fall_2025_Projects...     True
# 3  /projectnb/ec500kb/projects/Fall_2025_Projects...     True
# 4                                               None    False

# %% [markdown]
# <a id="step3"></a>
# ## Step 3 — XML parsing functions (instance and type maps)

# %%
from pathlib import Path
import pandas as pd

# Keep only rows where xml_path exists
pairs_df = pairs_df.copy()

def _exists(p):
    if p is None:
        return False
    try:
        return Path(p).exists()
    except Exception:
        return False

pairs_df["has_xml"] = pairs_df["xml_path"].apply(_exists)
xml_pairs_df = pairs_df[pairs_df["has_xml"]].reset_index(drop=True)

print("Total slides:", len(pairs_df))
print("Slides with XML:", len(xml_pairs_df))
display(xml_pairs_df.head(5))


from pathlib import Path
from xml.dom import minidom
import numpy as np
from skimage import draw

def parse_xml_to_maps(xml_path, image_shape, class_map, min_area=MIN_POLY_AREA):
    """
    Convert XML polygon annotations into instance and type maps.
    Returns (inst_map, type_map)
    """
    if xml_path is None:
        raise ValueError("xml_path is None. This slide likely has no annotation XML.")
    xml_path = Path(xml_path)
    if not xml_path.exists():
        raise FileNotFoundError(f"XML not found: {xml_path}")

    h, w = image_shape[:2]
    inst_map = np.zeros((h, w), dtype=np.int32)
    type_map = np.zeros((h, w), dtype=np.int32)
    inst_id = 1

    xmldoc = minidom.parse(str(xml_path))
    annotations = xmldoc.getElementsByTagName("Annotation")

    # Make a fast lookup: label -> class_id
    label_to_id = {v.strip().lower(): int(k) for k, v in class_map.items()}

    for ann in annotations:
        ann_label = None
        for attr in ann.getElementsByTagName("Attribute"):
            if attr.hasAttribute("Name"):
                ann_label = attr.getAttribute("Name").strip().lower()
                break
        if not ann_label:
            continue

        class_id = label_to_id.get(ann_label, None)
        if class_id is None:
            continue

        for reg in ann.getElementsByTagName("Region"):
            vertices = reg.getElementsByTagName("Vertex")
            if len(vertices) < 3:
                continue

            poly = np.array([(float(v.getAttribute("X")), float(v.getAttribute("Y")))
                             for v in vertices], dtype=np.float32)

            rr, cc = draw.polygon(poly[:, 1], poly[:, 0], (h, w))
            if len(rr) < min_area:
                continue

            inst_map[rr, cc] = inst_id
            type_map[rr, cc] = class_id
            inst_id += 1

    return inst_map, type_map



import numpy as np
import cv2
import matplotlib.pyplot as plt
from openslide import OpenSlide

sample_row = xml_pairs_df.iloc[0]
svs_path = sample_row["svs_path"]
xml_path = sample_row["xml_path"]

with OpenSlide(str(svs_path)) as slide:
    img = np.array(slide.read_region((0, 0), 0, slide.level_dimensions[0]))[:, :, :3]

inst_map, type_map = parse_xml_to_maps(xml_path, img.shape, class_map, min_area=MIN_POLY_AREA)

print("✅ Parsed:", Path(svs_path).name)
print(" - Image shape:", img.shape)
print(" - Unique instances:", inst_map.max())
print(" - Classes in type_map:", np.unique(type_map))

overlay = cv2.addWeighted(
    img, 0.6,
    cv2.applyColorMap(
        (type_map.astype(np.float32) / max(type_map.max(), 1) * 255).astype(np.uint8),
        cv2.COLORMAP_JET
    ),
    0.4, 0,
)

plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1); plt.imshow(img); plt.title("H&E (RGB)"); plt.axis("off")
plt.subplot(1, 3, 2); plt.imshow(type_map, cmap="nipy_spectral"); plt.title("type_map"); plt.axis("off")
plt.subplot(1, 3, 3); plt.imshow(cv2.cvtColor(overlay, cv2.COLOR_BGR2RGB)); plt.title("Overlay"); plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# Total slides: 31
# Slides with XML: 2
#                    patient                   image_name  \
# 0  TCGA-78-7152-01Z-00-DX1  TCGA-78-7152-01Z-00-DX1_001
# 1  TCGA-78-7152-01Z-00-DX1  TCGA-78-7152-01Z-00-DX1_002
#
#                                             svs_path  \
# 0  /projectnb/ec500kb/projects/Fall_2025_Projects...
# 1  /projectnb/ec500kb/projects/Fall_2025_Projects...
#
#                                             xml_path  has_xml
# 0  /projectnb/ec500kb/projects/Fall_2025_Projects...     True
# 1  /projectnb/ec500kb/projects/Fall_2025_Projects...     True
# ✅ Parsed: TCGA-78-7152-01Z-00-DX1_001.svs
#  - Image shape: (306, 443, 3)
#  - Unique instances: 16
#  - Classes in type_map: [0 1 3 5]

# %% [markdown]
# <a id="step4"></a>
# ## Step 4 — Generate and save instance/type maps for all slides

# %%
from tqdm import tqdm
from pathlib import Path
import numpy as np
import json
import pandas as pd
from openslide import OpenSlide

OUTPUT_ROOT = OUT_ROOT / "whole_slide"
(OUTPUT_ROOT / "inst_maps").mkdir(parents=True, exist_ok=True)
(OUTPUT_ROOT / "type_maps").mkdir(parents=True, exist_ok=True)

with open(OUT_ROOT / "_meta" / "class_map.json", "r") as f:
    class_map = json.load(f)
print(f"Loaded class_map: {class_map}")

def _xml_exists(p):
    if p is None:
        return False
    p = Path(p)
    return p.exists()

# ✅ Only slides that actually have XML
xml_pairs_df = pairs_df[pairs_df["xml_path"].apply(_xml_exists)].reset_index(drop=True)
print(f"Slides total: {len(pairs_df)} | with XML: {len(xml_pairs_df)}")

summary_records = []

for _, row in tqdm(xml_pairs_df.iterrows(), total=len(xml_pairs_df), desc="Processing annotated slides"):
    svs_path = Path(row["svs_path"])
    xml_path = Path(row["xml_path"])
    base = svs_path.stem

    if not svs_path.exists():
        print(f"⚠️ Missing slide: {svs_path}")
        continue

    try:
        with OpenSlide(str(svs_path)) as slide:
            w, h = slide.level_dimensions[0]

            # WARNING: this reads the full-res WSI into RAM
            rgb = np.array(slide.read_region((0, 0), 0, (w, h)))[:, :, :3]

        inst_map, type_map = parse_xml_to_maps(
            xml_path, rgb.shape, class_map, min_area=MIN_POLY_AREA
        )

        np.save(OUTPUT_ROOT / "inst_maps" / f"{base}_inst.npy", inst_map)
        np.save(OUTPUT_ROOT / "type_maps" / f"{base}_type.npy", type_map)

        summary_records.append({
            "slide": base,
            "instances": int(inst_map.max()),
            "classes_present": [int(x) for x in np.unique(type_map)],
            "height": int(h),
            "width": int(w),
            "xml": str(xml_path),
            "svs": str(svs_path),
        })

    except Exception as e:
        print(f"⚠️ Error processing {base}: {e}")

summary_df = pd.DataFrame(summary_records)
summary_csv = OUT_ROOT / "_meta" / "map_summary.csv"
summary_df.to_csv(summary_csv, index=False)

print(f"Saved summary → {summary_csv}")
display(summary_df)
# Out:
# Loaded class_map: {'0': 'background', '1': 'ambiguous', '2': 'epithelial', '3': 'lymphocyte', '4': 'macrophage', '5': 'neutrophil'}
# Slides total: 31 | with XML: 2
# Processing annotated slides: 100%|██████████| 2/2 [00:00<00:00, 12.30it/s]
# Saved summary → /projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/ProcessedDataset/v1_40x_area20_3/_meta/map_summary.csv
#                          slide  instances classes_present  height  width  \
# 0  TCGA-78-7152-01Z-00-DX1_001         16    [0, 1, 3, 5]     306    443
# 1  TCGA-78-7152-01Z-00-DX1_002          7       [0, 3, 4]     125    171
#
#                                                  xml  \
# 0  /projectnb/ec500kb/projects/Fall_2025_Projects...
# 1  /projectnb/ec500kb/projects/Fall_2025_Projects...
#
#                                                  svs
# 0  /projectnb/ec500kb/projects/Fall_2025_Projects...
# 1  /projectnb/ec500kb/projects/Fall_2025_Projects...
