# %% [markdown]
# # Dataset Exploration — Step 1: Understanding the Raw Data
#
# **Goal:**
# This notebook analyzes the *raw histopathology dataset* provided for testing and testing.
# We inspect file organization, patient counts, image formats (`.svs`, `.tif`), annotation structure (`.xml`), and metadata consistency between magnifications.
#
# ---
#
# ### Key Questions
# 1. How many patients are in the dataset?
# 2. What types of image files exist (`.svs`, `.tif`, `.xml`)?
# 3. Are dimensions consistent between `.svs` and `.tif`?
# 4. What is the typical resolution and size distribution of images?
# 5. What are the typical nucleus polygon areas and per-class area distributions?
#
# ---
#
# ### Table of Contents
# - [Step 1 — Inspect Dataset Archives](#step1)
# - [Step 2 — Explore File Types Inside the Archives](#step2)
# - [Step 3 — Collect Patient and Image Metadata](#step3)
# - [Step 4 — Visualize Image Dimensions](#step4)
# - [Step 5 — Validate .svs ↔ .tif Consistency](#step5)
# - [Step 6 — Polygon Area Distribution](#step6)
# - [Step 7 — Polygon Areas by Cell Type](#step7)
# - [Summary](#summary)

# %% [markdown]
# <a id="step1"></a>
# ## Step 1 — Inspect Dataset Archives

# %%
from pathlib import Path
import os
import zipfile
import pandas as pd
from openslide import OpenSlide

# === Paths ===
DATASETS_DIR = Path("/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/Datasets/BU_course_data")

test_ZIP = DATASETS_DIR / "testingData.zip"
TEST_ZIP  = DATASETS_DIR / "TestingData.zip"

# Unzipped directories (if already extracted)
TRAIN_DIR = DATASETS_DIR / "TrainingData" / "TrainingImages_and_Annotations"
TEST_DIR  = DATASETS_DIR / "TestingData"  / "TestingData"

TEST_DIR = Path("/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/TestDataTCGA/TestingData/TestingData")

for p in [TRAIN_ZIP, TEST_ZIP]:
    print("Exists:", p.exists(), p.name)
# Out:
# Exists: True TrainingData.zip
# Exists: True TestingData.zip

# %%
# !unzip -l /projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/Datasets/BU_course_data/TrainingData.zip | head -20
# Out:
# Archive:  /projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/Datasets/BU_course_data/TrainingData.zip
#   Length      Date    Time    Name
# ---------  ---------- -----   ----
#         0  09-18-2025 16:27   TrainingData/
#         0  09-18-2025 16:03   TrainingData/TrainingImages_and_Annotations/
#         0  09-18-2025 16:03   TrainingData/TrainingImages_and_Annotations/TCGA-55-1594-01Z-00-DX1/
#   2337213  09-18-2025 16:03   TrainingData/TrainingImages_and_Annotations/TCGA-55-1594-01Z-00-DX1/TCGA-55-1594-01Z-00-DX1_001.svs
#   3070138  09-18-2025 16:03   TrainingData/TrainingImages_and_Annotations/TCGA-55-1594-01Z-00-DX1/TCGA-55-1594-01Z-00-DX1_001.tif
#    954158  09-18-2025 16:03   TrainingData/TrainingImages_and_Annotations/TCGA-55-1594-01Z-00-DX1/TCGA-55-1594-01Z-00-DX1_001.xml
#   1002407  09-18-2025 16:03   TrainingData/TrainingImages_and_Annotations/TCGA-55-1594-01Z-00-DX1/TCGA-55-1594-01Z-00-DX1_002.svs
#    782414  09-18-2025 16:03   TrainingData/TrainingImages_and_Annotations/TCGA-55-1594-01Z-00-DX1/TCGA-55-1594-01Z-00-DX1_002.tif
#    615871  09-18-2025 16:03   TrainingData/TrainingImages_and_Annotations/TCGA-55-1594-01Z-00-DX1/TCGA-55-1594-01Z-00-DX1_002.xml
#    968143  09-18-2025 16:03   TrainingData/TrainingImages_and_Annotations/TCGA-55-1594-01Z-00-DX1/TCGA-55-1594-01Z-00-DX1_003.svs
#    737432  09-18-2025 16:03   TrainingData/TrainingImages_and_Annotations/TCGA-55-1594-01Z-00-DX1/TCGA-55-1594-01Z-00-DX1_003.tif
#    151907  09-18-2025 16:03   TrainingData/TrainingImages_and_Annotations/TCGA-55-1594-01Z-00-DX1/TCGA-55-1594-01Z-00-DX1_003.xml
#    947629  09-18-2025 16:03   TrainingData/TrainingImages_and_Annotations/TCGA-55-1594-01Z-00-DX1/TCGA-55-1594-01Z-00-DX1_004.svs
#    685124  09-18-2025 16:03   TrainingData/TrainingImages_and_Annotations/TCGA-55-1594-01Z-00-DX1/TCGA-55-1594-01Z-00-DX1_004.tif
#     59949  09-18-2025 16:03   TrainingData/TrainingImages_and_Annotations/TCGA-55-1594-01Z-00-DX1/TCGA-55-1594-01Z-00-DX1_004.xml
#   1025279  09-18-2025 16:03   TrainingData/TrainingImages_and_Annotations/TCGA-55-1594-01Z-00-DX1/TCGA-55-1594-01Z-00-DX1_005.svs
#    783816  09-18-2025 16:03   TrainingData/TrainingImages_and_Annotations/TCGA-55-1594-01Z-00-DX1/TCGA-55-1594-01Z-00-DX1_005.tif

# %%
# !unzip -l /projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/Datasets/BU_course_data/TestingData.zip | head -20
# Out:
# Archive:  /projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/Datasets/BU_course_data/TestingData.zip
#   Length      Date    Time    Name
# ---------  ---------- -----   ----
#         0  09-18-2025 16:43   TestingData/
#         0  09-18-2025 16:52   TestingData/TestingData/
#         0  09-18-2025 16:50   TestingData/TestingData/TCGA-55-7570-01Z-00-DX1/
#   1038865  09-18-2025 16:02   TestingData/TestingData/TCGA-55-7570-01Z-00-DX1/TCGA-55-7570-01Z-00-DX1_001.svs
#    875032  09-18-2025 16:02   TestingData/TestingData/TCGA-55-7570-01Z-00-DX1/TCGA-55-7570-01Z-00-DX1_001.tif
#    552233  09-18-2025 16:02   TestingData/TestingData/TCGA-55-7570-01Z-00-DX1/TCGA-55-7570-01Z-00-DX1_002.svs
#     93578  09-18-2025 16:02   TestingData/TestingData/TCGA-55-7570-01Z-00-DX1/TCGA-55-7570-01Z-00-DX1_002.tif
#         0  09-18-2025 16:02   TestingData/TestingData/TCGA-78-7152-01Z-00-DX1/
#    786761  09-18-2025 16:02   TestingData/TestingData/TCGA-78-7152-01Z-00-DX1/TCGA-78-7152-01Z-00-DX1_001.svs
#    334964  09-18-2025 16:02   TestingData/TestingData/TCGA-78-7152-01Z-00-DX1/TCGA-78-7152-01Z-00-DX1_001.tif
#     48677  09-18-2025 16:02   TestingData/TestingData/TCGA-78-7152-01Z-00-DX1/TCGA-78-7152-01Z-00-DX1_001.xml
#    578143  09-18-2025 16:02   TestingData/TestingData/TCGA-78-7152-01Z-00-DX1/TCGA-78-7152-01Z-00-DX1_002.svs
#     57120  09-18-2025 16:02   TestingData/TestingData/TCGA-78-7152-01Z-00-DX1/TCGA-78-7152-01Z-00-DX1_002.tif
#     40355  09-18-2025 16:02   TestingData/TestingData/TCGA-78-7152-01Z-00-DX1/TCGA-78-7152-01Z-00-DX1_002.xml
#         0  09-18-2025 16:52   TestingData/TestingData/TCGA-A2-A04X-01Z-00-DX1/
#   2128035  09-18-2025 16:02   TestingData/TestingData/TCGA-A2-A04X-01Z-00-DX1/TCGA-A2-A04X-01Z-00-DX1_001.svs
#   2684070  09-18-2025 16:02   TestingData/TestingData/TCGA-A2-A04X-01Z-00-DX1/TCGA-A2-A04X-01Z-00-DX1_001.tif
# Archive:  /projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/Datasets/BU_course_data/TestingData.zip
#    creating: TestingData/
#    creating: TestingData/TestingData/
#    creating: TestingData/TestingData/TCGA-55-7570-01Z-00-DX1/
#   inflating: TestingData/TestingData/TCGA-55-7570-01Z-00-DX1/TCGA-55-7570-01Z-00-DX1_001.svs
#   inflating: TestingData/TestingData/TCGA-55-7570-01Z-00-DX1/TCGA-55-7570-01Z-00-DX1_001.tif
#   inflating: TestingData/TestingData/TCGA-55-7570-01Z-00-DX1/TCGA-55-7570-01Z-00-DX1_002.svs
#   inflating: TestingData/TestingData/TCGA-55-7570-01Z-00-DX1/TCGA-55-7570-01Z-00-DX1_002.tif
#    creating: TestingData/TestingData/TCGA-78-7152-01Z-00-DX1/
#   inflating: TestingData/TestingData/TCGA-78-7152-01Z-00-DX1/TCGA-78-7152-01Z-00-DX1_001.svs
#   inflating: TestingData/TestingData/TCGA-78-7152-01Z-00-DX1/TCGA-78-7152-01Z-00-DX1_001.tif
#   inflating: TestingData/TestingData/TCGA-78-7152-01Z-00-DX1/TCGA-78-7152-01Z-00-DX1_001.xml
#   inflating: TestingData/TestingData/TCGA-78-7152-01Z-00-DX1/TCGA-78-7152-01Z-00-DX1_002.svs
#   inflating: TestingData/TestingData/TCGA-78-7152-01Z-00-DX1/TCGA-78-7152-01Z-00-DX1_002.tif
#   inflating: TestingData/TestingData/TCGA-78-7152-01Z-00-DX1/TCGA-78-7152-01Z-00-DX1_002.xml
#    creating: TestingData/TestingData/TCGA-A2-A04X-01Z-00-DX1/
#   inflating: TestingData/TestingData/TCGA-A2-A04X-01Z-00-DX1/TCGA-A2-A04X-01Z-00-DX1_001.svs
#   inflating: TestingData/TestingData/TCGA-A2-A04X-01Z-00-DX1/TCGA-A2-A04X-01Z-00-DX1_001.tif
#   inflating: TestingData/TestingData/TCGA-A2-A04X-01Z-00-DX1/TCGA-A2-A04X-01Z-00-DX1_002.svs
#   inflating: TestingData/TestingData/TCGA-A2-A04X-01Z-00-DX1/TCGA-A2-A04X-01Z-00-DX1_002.tif
#   inflating: TestingData/TestingData/TCGA-A2-A04X-01Z-00-DX1/TCGA-A2-A04X-01Z-00-DX1_003.svs
#   inflating: TestingData/TestingData/TCGA-A2-A04X-01Z-00-DX1/TCGA-A2-A04X-01Z-00-DX1_003.tif
#   inflating: TestingData/TestingData/TCGA-A2-A04X-01Z-00-DX1/TCGA-A2-A04X-01Z-00-DX1_004.svs
#   inflating: TestingData/TestingData/TCGA-A2-A04X-01Z-00-DX1/TCGA-A2-A04X-01Z-00-DX1_004.tif
#    creating: TestingData/TestingData/TCGA-A2-A0ES-01Z-00-DX1/
#   inflating: TestingData/TestingData/TCGA-A2-A0ES-01Z-00-DX1/TCGA-A2-A0ES-01Z-00-DX1_001.svs
#   inflating: TestingData/TestingData/TCGA-A2-A0ES-01Z-00-DX1/TCGA-A2-A0ES-01Z-00-DX1_001.tif
#   inflating: TestingData/TestingData/TCGA-A2-A0ES-01Z-00-DX1/TCGA-A2-A0ES-01Z-00-DX1_002.svs
#   inflating: TestingData/TestingData/TCGA-A2-A0ES-01Z-00-DX1/TCGA-A2-A0ES-01Z-00-DX1_002.tif
#   inflating: TestingData/TestingData/TCGA-A2-A0ES-01Z-00-DX1/TCGA-A2-A0ES-01Z-00-DX1_003.svs
#   inflating: TestingData/TestingData/TCGA-A2-A0ES-01Z-00-DX1/TCGA-A2-A0ES-01Z-00-DX1_004.svs
#    creating: TestingData/TestingData/TCGA-DW-7838-01Z-00-DX1/
#   inflating: TestingData/TestingData/TCGA-DW-7838-01Z-00-DX1/TCGA-DW-7838-01Z-00-DX1_1.svs
#   inflating: TestingData/TestingData/TCGA-DW-7838-01Z-00-DX1/TCGA-DW-7838-01Z-00-DX1_1.tif
#   inflating: TestingData/TestingData/TCGA-DW-7838-01Z-00-DX1/TCGA-DW-7838-01Z-00-DX1_2.svs
#   inflating: TestingData/TestingData/TCGA-DW-7838-01Z-00-DX1/TCGA-DW-7838-01Z-00-DX1_2.tif
#   inflating: TestingData/TestingData/TCGA-DW-7838-01Z-00-DX1/TCGA-DW-7838-01Z-00-DX1_3.svs
#   inflating: TestingData/TestingData/TCGA-DW-7838-01Z-00-DX1/TCGA-DW-7838-01Z-00-DX1_3.tif
#   inflating: TestingData/TestingData/TCGA-DW-7838-01Z-00-DX1/TCGA-DW-7838-01Z-00-DX1_4.svs
#   inflating: TestingData/TestingData/TCGA-DW-7838-01Z-00-DX1/TCGA-DW-7838-01Z-00-DX1_4.tif
#   inflating: TestingData/TestingData/TCGA-DW-7838-01Z-00-DX1/TCGA-DW-7838-01Z-00-DX1_5.svs
#   inflating: TestingData/TestingData/TCGA-DW-7838-01Z-00-DX1/TCGA-DW-7838-01Z-00-DX1_5.tif
#    creating: TestingData/TestingData/TCGA-F9-A8NY-01Z-00-DX1/
#   inflating: TestingData/TestingData/TCGA-F9-A8NY-01Z-00-DX1/TCGA-F9-A8NY-01Z-00-DX1_1.svs
#   inflating: TestingData/TestingData/TCGA-F9-A8NY-01Z-00-DX1/TCGA-F9-A8NY-01Z-00-DX1_1.tif
#   inflating: TestingData/TestingData/TCGA-F9-A8NY-01Z-00-DX1/TCGA-F9-A8NY-01Z-00-DX1_2.svs
#   inflating: TestingData/TestingData/TCGA-F9-A8NY-01Z-00-DX1/TCGA-F9-A8NY-01Z-00-DX1_2.tif
#   inflating: TestingData/TestingData/TCGA-F9-A8NY-01Z-00-DX1/TCGA-F9-A8NY-01Z-00-DX1_3.svs
#   inflating: TestingData/TestingData/TCGA-F9-A8NY-01Z-00-DX1/TCGA-F9-A8NY-01Z-00-DX1_3.tif
#   inflating: TestingData/TestingData/TCGA-F9-A8NY-01Z-00-DX1/TCGA-F9-A8NY-01Z-00-DX1_4.svs
#   inflating: TestingData/TestingData/TCGA-F9-A8NY-01Z-00-DX1/TCGA-F9-A8NY-01Z-00-DX1_4.tif
#    creating: TestingData/TestingData/TCGA-VP-A87E-01Z-00-DX1/
#   inflating: TestingData/TestingData/TCGA-VP-A87E-01Z-00-DX1/TCGA-VP-A87E-01Z-00-DX1_1.svs
#   inflating: TestingData/TestingData/TCGA-VP-A87E-01Z-00-DX1/TCGA-VP-A87E-01Z-00-DX1_1.tif
#   inflating: TestingData/TestingData/TCGA-VP-A87E-01Z-00-DX1/TCGA-VP-A87E-01Z-00-DX1_2.svs
#   inflating: TestingData/TestingData/TCGA-VP-A87E-01Z-00-DX1/TCGA-VP-A87E-01Z-00-DX1_2.tif
#   inflating: TestingData/TestingData/TCGA-VP-A87E-01Z-00-DX1/TCGA-VP-A87E-01Z-00-DX1_3.svs
#   inflating: TestingData/TestingData/TCGA-VP-A87E-01Z-00-DX1/TCGA-VP-A87E-01Z-00-DX1_3.tif
#   inflating: TestingData/TestingData/TCGA-VP-A87E-01Z-00-DX1/TCGA-VP-A87E-01Z-00-DX1_4.svs
#   inflating: TestingData/TestingData/TCGA-VP-A87E-01Z-00-DX1/TCGA-VP-A87E-01Z-00-DX1_4.tif
#   inflating: TestingData/TestingData/TCGA-VP-A87E-01Z-00-DX1/TCGA-VP-A87E-01Z-00-DX1_5.svs
#   inflating: TestingData/TestingData/TCGA-VP-A87E-01Z-00-DX1/TCGA-VP-A87E-01Z-00-DX1_5.tif
#    creating: TestingData/TestingData/TCGA-X4-A8KS-01Z-00-DX3/
#   inflating: TestingData/TestingData/TCGA-X4-A8KS-01Z-00-DX3/TCGA-X4-A8KS-01Z-00-DX3_1.svs
#   inflating: TestingData/TestingData/TCGA-X4-A8KS-01Z-00-DX3/TCGA-X4-A8KS-01Z-00-DX3_1.tif
#    creating: TestingData/TestingData/TCGA-YL-A9WL-01Z-00-DX1/
#   inflating: TestingData/TestingData/TCGA-YL-A9WL-01Z-00-DX1/TCGA-YL-A9WL-01Z-00-DX1_1.svs
#   inflating: TestingData/TestingData/TCGA-YL-A9WL-01Z-00-DX1/TCGA-YL-A9WL-01Z-00-DX1_1.tif
#   inflating: TestingData/TestingData/TCGA-YL-A9WL-01Z-00-DX1/TCGA-YL-A9WL-01Z-00-DX1_2.svs
#   inflating: TestingData/TestingData/TCGA-YL-A9WL-01Z-00-DX1/TCGA-YL-A9WL-01Z-00-DX1_2.tif
#   inflating: TestingData/TestingData/TCGA-YL-A9WL-01Z-00-DX1/TCGA-YL-A9WL-01Z-00-DX1_3.svs
#   inflating: TestingData/TestingData/TCGA-YL-A9WL-01Z-00-DX1/TCGA-YL-A9WL-01Z-00-DX1_3.tif
#   inflating: TestingData/TestingData/TCGA-YL-A9WL-01Z-00-DX1/TCGA-YL-A9WL-01Z-00-DX1_4.svs
#   inflating: TestingData/TestingData/TCGA-YL-A9WL-01Z-00-DX1/TCGA-YL-A9WL-01Z-00-DX1_4.tif

# %% [markdown]
# ##### ..._001.svs   → original microscopy file (Openslide to read)
# ##### ..._001.tif   → same image exported from .svs (for convenience)
# ##### ..._001.xml   → annotation polygons (cell boundaries + labels)

# %% [markdown]
# <a id="step2"></a>
# ## Step 2 — Explore File Types Inside the Archives

# %%
from zipfile import ZipFile
from collections import Counter

def inspect_zip(zip_path, max_preview=20):
    """
    Inspect a zip file: list internal files, count by extension,
    and preview the first few lines of its directory tree.
    """
    if not zip_path.exists():
        print(f"❌ Zip not found: {zip_path}")
        return None, None
    
    with ZipFile(zip_path, 'r') as zf:
        files = zf.namelist()
    
    print(f"\n🧭 {zip_path.name}: {len(files)} total files")
    
    # Count file extensions
    exts = Counter([Path(f).suffix.lower() for f in files if not f.endswith("/")])
    df = pd.DataFrame({"ext": list(exts.keys()), "count": list(exts.values())}).sort_values("count", ascending=False)
    
    print("\nTop file types:")
    display(df)
    
    print("\nPreview of internal structure:")
    for f in files[:max_preview]:
        print(" ", f)
    
    return files, df


test_files,  test_summary  = inspect_zip(TEST_ZIP)
# Out:
# 🧭 TestingData.zip: 73 total files
#
# Top file types:
#     ext  count
# 0  .svs     31
# 1  .tif     29
# 2  .xml      2
# Preview of internal structure:
#   TestingData/
#   TestingData/TestingData/
#   TestingData/TestingData/TCGA-55-7570-01Z-00-DX1/
#   TestingData/TestingData/TCGA-55-7570-01Z-00-DX1/TCGA-55-7570-01Z-00-DX1_001.svs
#   TestingData/TestingData/TCGA-55-7570-01Z-00-DX1/TCGA-55-7570-01Z-00-DX1_001.tif
#   TestingData/TestingData/TCGA-55-7570-01Z-00-DX1/TCGA-55-7570-01Z-00-DX1_002.svs
#   TestingData/TestingData/TCGA-55-7570-01Z-00-DX1/TCGA-55-7570-01Z-00-DX1_002.tif
#   TestingData/TestingData/TCGA-78-7152-01Z-00-DX1/
#   TestingData/TestingData/TCGA-78-7152-01Z-00-DX1/TCGA-78-7152-01Z-00-DX1_001.svs
#   TestingData/TestingData/TCGA-78-7152-01Z-00-DX1/TCGA-78-7152-01Z-00-DX1_001.tif
#   TestingData/TestingData/TCGA-78-7152-01Z-00-DX1/TCGA-78-7152-01Z-00-DX1_001.xml
#   TestingData/TestingData/TCGA-78-7152-01Z-00-DX1/TCGA-78-7152-01Z-00-DX1_002.svs
#   TestingData/TestingData/TCGA-78-7152-01Z-00-DX1/TCGA-78-7152-01Z-00-DX1_002.tif
#   TestingData/TestingData/TCGA-78-7152-01Z-00-DX1/TCGA-78-7152-01Z-00-DX1_002.xml
#   TestingData/TestingData/TCGA-A2-A04X-01Z-00-DX1/
#   TestingData/TestingData/TCGA-A2-A04X-01Z-00-DX1/TCGA-A2-A04X-01Z-00-DX1_001.svs
#   TestingData/TestingData/TCGA-A2-A04X-01Z-00-DX1/TCGA-A2-A04X-01Z-00-DX1_001.tif
#   TestingData/TestingData/TCGA-A2-A04X-01Z-00-DX1/TCGA-A2-A04X-01Z-00-DX1_002.svs
#   TestingData/TestingData/TCGA-A2-A04X-01Z-00-DX1/TCGA-A2-A04X-01Z-00-DX1_002.tif
#   TestingData/TestingData/TCGA-A2-A04X-01Z-00-DX1/TCGA-A2-A04X-01Z-00-DX1_003.svs

# %% [markdown]
# <a id="step3"></a>
# ## Step 3 — Collect Patient and Image Metadata

# %%
from tqdm import tqdm
import pandas as pd
from openslide import OpenSlide

def gather_patient_metadata(root_dir: Path):
    records = []
    patients = sorted([d for d in root_dir.iterdir() if d.is_dir()])
    print(f"🧬 Found {len(patients)} patient folders\n")

    for patient_path in tqdm(patients, desc="Scanning patients"):
        patient_id = patient_path.name
        svs_files = sorted(patient_path.glob("*.svs"))
        tif_files = sorted(patient_path.glob("*.tif"))

        for img_path in svs_files + tif_files:
            img_name = img_path.stem
            xml_path = img_path.with_suffix(".xml")
            has_xml = xml_path.exists()
            width = height = None
            try:
                with OpenSlide(str(img_path)) as slide:
                    width, height = slide.dimensions
            except Exception as e:
                # sometimes .tif can't be opened with OpenSlide
                try:
                    import cv2
                    img = cv2.imread(str(img_path))
                    if img is not None:
                        height, width = img.shape[:2]
                except:
                    pass

            records.append({
                "patient": patient_id,
                "image": img_name,
                "format": img_path.suffix.lower(),
                "width": width,
                "height": height,
                "has_xml": has_xml
            })

    return pd.DataFrame(records)

test_metadata = gather_patient_metadata(TEST_DIR)
display(test_metadata.head())

print(f"\nTotal images scanned: {len(test_metadata)}")
print(test_metadata.groupby('patient').size().describe())
# Out:
# 🧬 Found 9 patient folders
# Scanning patients: 100%|██████████| 9/9 [00:01<00:00,  6.35it/s]
#                    patient                        image format  width  height  \
# 0  TCGA-55-7570-01Z-00-DX1  TCGA-55-7570-01Z-00-DX1_001   .svs    310     950
# 1  TCGA-55-7570-01Z-00-DX1  TCGA-55-7570-01Z-00-DX1_002   .svs    219     157
# 2  TCGA-55-7570-01Z-00-DX1  TCGA-55-7570-01Z-00-DX1_001   .tif    310     950
# 3  TCGA-55-7570-01Z-00-DX1  TCGA-55-7570-01Z-00-DX1_002   .tif    219     157
# 4  TCGA-78-7152-01Z-00-DX1  TCGA-78-7152-01Z-00-DX1_001   .svs    443     306
#
#    has_xml
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Total images scanned: 60
# count     9.000000
# mean      6.666667
# std       2.828427
# min       2.000000
# 25%       4.000000
# 50%       8.000000
# 75%       8.000000
# max      10.000000
# dtype: float64

# %% [markdown]
# <a id="step4"></a>
# ## Step 4 — Visualize Image Dimensions

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Drop missing dimension rows
#valid_dims = test_metadata.dropna(subset=["width", "height"]).copy()
valid_dims = test_metadata.query("format == '.tif'").dropna(subset=['width','height']).copy()

# Compute area (pixels)
valid_dims["area"] = valid_dims["width"] * valid_dims["height"]

# --- 1. Summary table ---
print("Unique resolutions and their counts:")
res_counts = valid_dims.groupby(["width", "height"]).size().reset_index(name="count")
display(res_counts.sort_values("count", ascending=False))

# --- 2. Histogram of image sizes ---
plt.figure(figsize=(8,5))
sns.histplot(valid_dims["width"], bins=20, color="skyblue", label="widths", kde=True)
sns.histplot(valid_dims["height"], bins=20, color="salmon", label="heights", kde=True)
plt.xlabel("Dimension (pixels)")
plt.ylabel("Frequency")
plt.title("Distribution of Image Widths and Heights")
plt.legend()
plt.show()

# --- 3. 2D heatmap of width vs height ---
plt.figure(figsize=(6,6))
sns.kdeplot(data=valid_dims, x="width", y="height", fill=True, cmap="mako")
plt.title("Image Resolution Density")
plt.xlabel("Width (px)")
plt.ylabel("Height (px)")
plt.show()

# --- 4. Optional: show how many 512×512 images, etc. ---
specific_size = (512, 512)
count_512 = ((valid_dims["width"] == specific_size[0]) & (valid_dims["height"] == specific_size[1])).sum()
print(f"\nNumber of {specific_size[0]}×{specific_size[1]} images: {count_512}")
# Out:
# Unique resolutions and their counts:
#     width  height  count
# 0     114     123      1
# 15    497     384      1
# 27   1401    2150      1
# 26   1007     912      1
# 25    935     449      1
# 24    892     781      1
# 23    858     523      1
# 22    796     567      1
# 21    787     655      1
# 20    736     556      1
# 19    726     879      1
# 18    676     578      1
# 17    664     653      1
# 16    512     446      1
# 14    464     201      1
# 1     124     134      1
# 13    448     309      1
# 12    443     306      1
# 11    388     849      1
# 10    341     293      1
# 9     310     950      1
# 8     296     297      1
# 7     224     134      1
# 6     219     157      1
# 5     177     316      1
# 4     171     125      1
# 3     170     255      1
# 2     147     151      1
# 28   1872    1400      1
# Number of 512×512 images: 0

# %% [markdown]
# <a id="step5"></a>
# ## Step 5 — Validate .svs ↔ .tif Consistency

# %%
import pandas as pd
from openslide import OpenSlide

def compare_svs_tif_dimensions(root_dir: Path):
    rows = []
    patients = sorted([d for d in root_dir.iterdir() if d.is_dir()])

    for patient_path in patients:
        patient_id = patient_path.name
        svs_files = sorted(patient_path.glob("*.svs"))
        for svs_path in svs_files:
            base = svs_path.stem
            tif_path = patient_path / f"{base}.tif"
            xml_path = patient_path / f"{base}.xml"

            # read svs dims
            svs_w = svs_h = tif_w = tif_h = None
            try:
                with OpenSlide(str(svs_path)) as slide:
                    svs_w, svs_h = slide.dimensions
            except Exception as e:
                print("⚠️ failed to read", svs_path.name, e)

            # read tif dims (fallback to cv2 if OpenSlide fails)
            if tif_path.exists():
                try:
                    with OpenSlide(str(tif_path)) as slide:
                        tif_w, tif_h = slide.dimensions
                except Exception:
                    import cv2
                    img = cv2.imread(str(tif_path))
                    if img is not None:
                        tif_h, tif_w = img.shape[:2]

            rows.append({
                "patient": patient_id,
                "base": base,
                "svs_w": svs_w, "svs_h": svs_h,
                "tif_w": tif_w, "tif_h": tif_h,
                "has_xml": xml_path.exists()
            })

    df = pd.DataFrame(rows)
    df["match"] = (df["svs_w"] == df["tif_w"]) & (df["svs_h"] == df["tif_h"])
    return df

compare_df = compare_svs_tif_dimensions(TEST_DIR)
display(compare_df.head())

# --- Summary ---
print("\n✅ Dimension comparison summary:")
print(compare_df["match"].value_counts())
print("\nNon-matching examples (if any):")
display(compare_df[~compare_df["match"]])
# Out:
#                    patient                         base  svs_w  svs_h   tif_w  \
# 0  TCGA-55-7570-01Z-00-DX1  TCGA-55-7570-01Z-00-DX1_001    310    950   310.0
# 1  TCGA-55-7570-01Z-00-DX1  TCGA-55-7570-01Z-00-DX1_002    219    157   219.0
# 2  TCGA-78-7152-01Z-00-DX1  TCGA-78-7152-01Z-00-DX1_001    443    306   443.0
# 3  TCGA-78-7152-01Z-00-DX1  TCGA-78-7152-01Z-00-DX1_002    171    125   171.0
# 4  TCGA-A2-A04X-01Z-00-DX1  TCGA-A2-A04X-01Z-00-DX1_001   1007    912  1007.0
#
#    tif_h  has_xml  match
# 0  950.0    False   True
# 1  157.0    False   True
# 2  306.0     True   True
# 3  125.0     True   True
# 4  912.0    False   True
# ✅ Dimension comparison summary:
# True     29
# False     2
# Name: match, dtype: int64
#
# Non-matching examples (if any):
#                     patient                         base  svs_w  svs_h  tif_w  \
# 10  TCGA-A2-A0ES-01Z-00-DX1  TCGA-A2-A0ES-01Z-00-DX1_003    634    171    NaN
# 11  TCGA-A2-A0ES-01Z-00-DX1  TCGA-A2-A0ES-01Z-00-DX1_004    393    229    NaN
#
#     tif_h  has_xml  match
# 10    NaN    False  False
# 11    NaN    False  False

# %% [markdown]
# So, all of them are matching with 40x as expected.

# %% [markdown]
# <a id="step6"></a>
# ## Step 6 — Polygon Area Distribution

# %%
from pathlib import Path
from xml.dom import minidom
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

RAW_ROOT = TEST_DIR

def collect_polygon_areas(root_dir: Path, max_files=50):
    """Parse up to `max_files` XMLs and record each nucleus polygon area (in pixels)."""
    areas = []
    xml_files = list(root_dir.glob("**/*.xml"))[:max_files]
    print(f"Scanning {len(xml_files)} XML files...")

    for xml_path in xml_files:
        xmldoc = minidom.parse(str(xml_path))
        for reg in xmldoc.getElementsByTagName("Region"):
            vertices = reg.getElementsByTagName("Vertex")
            if len(vertices) < 3:
                continue
            poly = np.array([(float(v.getAttribute("X")), float(v.getAttribute("Y"))) for v in vertices])
            # Shoelace formula for polygon area
            area = 0.5 * np.abs(np.dot(poly[:,0], np.roll(poly[:,1], 1)) - np.dot(poly[:,1], np.roll(poly[:,0], 1)))
            areas.append(area)
    return np.array(areas)

areas = collect_polygon_areas(RAW_ROOT, max_files=30)
print(f"Collected {len(areas):,} polygons")

# --- Summary statistics ---
print(f"min={areas.min():.1f}, median={np.median(areas):.1f}, mean={areas.mean():.1f}, 95th={np.percentile(areas,95):.1f}")

# --- Plot distribution ---
plt.figure(figsize=(7,4))
sns.histplot(areas, bins=100, log_scale=True)
plt.xlabel("Polygon area (pixels², log scale)")
plt.ylabel("Count")
plt.title("Distribution of annotated nucleus polygon areas")
plt.show()
# Out:
# Scanning 2 XML files...
# Collected 23 polygons
# min=154.5, median=406.5, mean=615.3, 95th=2036.3

# %% [markdown]
# <a id="step7"></a>
# ## Step 7 — Polygon Areas by Cell Type

# %%
from xml.dom import minidom
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path


def collect_polygon_areas_with_labels(root_dir: Path, max_files=50):
    """Collect polygon areas and associated cell type labels from XML annotations."""
    records = []
    xml_files = list(root_dir.glob("**/*.xml"))[:max_files]
    print(f"Scanning {len(xml_files)} XML files...")

    for xml_path in xml_files:
        xmldoc = minidom.parse(str(xml_path))
        for ann in xmldoc.getElementsByTagName("Annotation"):
            # get cell type label from <Attribute Name="...">
            ann_label = None
            for attr in ann.getElementsByTagName("Attribute"):
                if attr.hasAttribute("Name"):
                    ann_label = attr.getAttribute("Name").strip().lower()
                    break
            if not ann_label:
                continue

            for reg in ann.getElementsByTagName("Region"):
                vertices = reg.getElementsByTagName("Vertex")
                if len(vertices) < 3:
                    continue
                poly = np.array([(float(v.getAttribute("X")), float(v.getAttribute("Y"))) for v in vertices])
                # Shoelace formula for polygon area
                area = 0.5 * np.abs(np.dot(poly[:,0], np.roll(poly[:,1], 1)) - np.dot(poly[:,1], np.roll(poly[:,0], 1)))
                records.append({"cell_type": ann_label, "area": area, "file": xml_path.name})

    return pd.DataFrame(records)

areas_df = collect_polygon_areas_with_labels(RAW_ROOT, max_files=30)
print(f"Collected {len(areas_df):,} polygons")

# --- Clean and summarize ---
areas_df["cell_type"] = areas_df["cell_type"].str.lower().str.strip()
areas_df = areas_df[areas_df["area"] > 0]

summary = areas_df.groupby("cell_type")["area"].describe()[["count", "mean", "50%", "min", "max"]]
display(summary)

# --- Plot: log-scale histograms per cell type ---
plt.figure(figsize=(9,5))
ax = sns.histplot(
    data=areas_df,
    x="area",
    hue="cell_type",
    bins=100,
    log_scale=True,
    element="step",
    common_norm=False,
    palette="tab10"
)
plt.xlabel("Polygon area (pixels², log scale)")
plt.ylabel("Count")
plt.title("Distribution of nucleus polygon areas per cell type (log scale)")

# Fix legend: let seaborn handle it properly
handles, labels = ax.get_legend_handles_labels()
if labels:
    plt.legend(handles=handles, labels=labels, title="Cell Type")
else:
    print("⚠️ No legend labels found — check if 'cell_type' column is populated.")

plt.tight_layout()
plt.show()
# Out:
# Scanning 2 XML files...
# Collected 23 polygons
#             count         mean      50%    min     max
# cell_type
# ambiguous     2.0   409.500000   409.50  364.5   454.5
# lymphocyte   10.0   186.000000   186.75  154.5   215.5
# macrophage    6.0  1475.833333  1323.50  747.0  2181.5
# neutrophil    5.0   523.700000   544.00  406.5   578.0
# ⚠️ No legend labels found — check if 'cell_type' column is populated.

# %% [markdown]
# <a id="step7"></a>
# ## Step 7 — Summary (TODO)
