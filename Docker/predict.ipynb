# %% [markdown]
# Imports & Setup

# %%
import sys
sys.path.append("/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN")
sys.path.append("/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/CellViT-plus-plus")

# %%
mkdir -p /projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/Docker/checkpoints

# %%
from huggingface_hub import hf_hub_download

local_ckpt = hf_hub_download(
    repo_id="BerkTuzcuBU/SamH-Rosie-FiLM-256",
    filename="SamH-Rosie-FiLM-256.pth",
    cache_dir="/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/Docker/checkpoints",
    local_dir="/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/Docker/checkpoints",
    local_dir_use_symlinks=False, 
)
print(local_ckpt)
# Out:
# SamH-Rosie-FiLM-256.pth:   0%|          | 0.00/8.60G [00:00<?, ?B/s]
# /projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/Docker/checkpoints/SamH-Rosie-FiLM-256.pth

# %%
local_ckpt
# Out:
# '/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/Docker/checkpoints/SamH-Rosie-FiLM-256.pth'

# %%
from src.inference import load_model

model = load_model("SamH_Rosie_FiLM_256", device="cpu")
print("Model loaded!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from src.inference import load_model
#       3 model = load_model("SamH_Rosie_FiLM_256", device="cpu")
#       4 print("Model loaded!")
#
# File /projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/Docker/src/inference.py:6
#       4 from PIL import Image
#       5 import numpy as np
# ----> 6 from cellvit.models.cell_segmentation.cellvit_sam_rosie_film import CellViTSAMRosieFiLM
#       7 from huggingface_hub import hf_hub_download
#      10 # ------------------------------------------------------
#      11 # 1. MODEL REPOSITORY DEFINITIONS
#      12 # ------------------------------------------------------
#
# ...
