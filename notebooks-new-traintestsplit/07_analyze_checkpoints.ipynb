# %% [markdown]
# ## Notes
#
# Using virchow could be better since it is already pretrained in histology images. We just need to finetune that.
#
# We need 256x256 images.
#
# In this notebook I'll analyze what the checkpoint that they give us includes and what we get out of the trainings.

# %%
import torch
from collections import defaultdict
import numpy as np

# ---------------------------------------------------------
# 1. Load checkpoint safely
# ---------------------------------------------------------
def load_checkpoint(path):
    print(f"📂 Loading checkpoint: {path}")
    ckpt = torch.load(path, map_location="cpu")
    print(f"✔ Loaded successfully.\n")
    return ckpt

# ---------------------------------------------------------
# 2. Print top-level structure
# ---------------------------------------------------------
def print_top_level(ckpt):
    print("==== 🔍 TOP-LEVEL KEYS ====")
    for k in ckpt.keys():
        print(" •", k)
    print()

# ---------------------------------------------------------
# 3. Get model_state_dict and categorize keys
# ---------------------------------------------------------
def analyze_state_dict(ckpt):
    sd = ckpt.get("model_state_dict", {})
    print(f"==== 📦 MODEL STATE DICT ({len(sd)} params) ====\n")

    categories = defaultdict(list)

    for k, v in sd.items():
        if k.startswith("encoder."):
            categories["encoder"].append(k)
        elif k.startswith("decoder.") or "head" in k.lower():
            categories["decoder"].append(k)
        else:
            categories["other"].append(k)

    for cat, keys in categories.items():
        print(f"--- {cat.upper()} ({len(keys)} keys) ---")
        for k in keys[:20]:            # print only first 20
            print("  -", k)
        if len(keys) > 20:
            print(f"  ... and {len(keys)-20} more")
        print()

    return categories

# ---------------------------------------------------------
# 4. Print parameter shapes
# ---------------------------------------------------------
def print_shapes(ckpt, filter_prefix=None, max_items=20):
    sd = ckpt.get("model_state_dict", {})
    print("==== 🔢 SHAPES ====\n")
    count = 0

    for k, v in sd.items():
        if filter_prefix and not k.startswith(filter_prefix):
            continue
        print(f"{k:60} {tuple(v.shape)}")
        count += 1
        if count >= max_items:
            print("... truncated ...\n")
            break

# ---------------------------------------------------------
# 5. Count total parameters
# ---------------------------------------------------------
def count_params(ckpt):
    sd = ckpt.get("model_state_dict", {})
    total = sum(np.prod(v.shape) for v in sd.values())
    print(f"==== 🧮 TOTAL PARAMETERS ====")
    print(f"Total: {total:,} parameters\n")
    return total

# ---------------------------------------------------------
# 6. Extract encoder-only weights
# ---------------------------------------------------------
def extract_encoder(ckpt):
    sd = ckpt.get("model_state_dict", {})
    encoder_sd = {k.replace("encoder.", ""): v for k, v in sd.items() if k.startswith("encoder.")}
    print(f"==== 🎯 ENCODER EXTRACT ====")
    print(f"Extracted {len(encoder_sd)} encoder weights\n")
    return encoder_sd

# ---------------------------------------------------------
# 7. Compare two checkpoints
# ---------------------------------------------------------
def compare_checkpoints(ckpt1, ckpt2):
    sd1 = ckpt1.get("model_state_dict", {})
    sd2 = ckpt2.get("model_state_dict", {})

    print("==== 🔍 COMPARISON ====\n")

    keys1 = set(sd1.keys())
    keys2 = set(sd2.keys())

    print("Missing in ckpt2:")
    for k in sorted(keys1 - keys2):
        print("  -", k)
    print()

    print("Missing in ckpt1:")
    for k in sorted(keys2 - keys1):
        print("  -", k)
    print()

    print("==== Shape mismatches ====")
    for k in sorted(keys1 & keys2):
        if sd1[k].shape != sd2[k].shape:
            print(f"  {k}: {tuple(sd1[k].shape)}  vs  {tuple(sd2[k].shape)}")

    print()

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict


# ---------------------------------------------------------
# 0) Paths
# ---------------------------------------------------------
ckpt1_path = "/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/CellViT-plus-plus/checkpoints/Virchow/CellViT-Virchow-x40-AMP.pth"
ckpt2_path = "/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/ProcessedDataset/v1_40x_area20/patches_cellvit_p128_pannuke/logs_local/2025-11-15T150541_tcga_finetune_128_reheat/checkpoints/model_best.pth"


# ---------------------------------------------------------
# 1) Load checkpoint safely
# ---------------------------------------------------------
def load_checkpoint(path):
    print(f"📂 Loading checkpoint: {path}")
    ckpt = torch.load(path, map_location="cpu", weights_only=False)
    print(f"✔ Loaded successfully.\n")
    return ckpt


# ---------------------------------------------------------
# 2) Print top-level structure
# ---------------------------------------------------------
def print_top_level(ckpt, name="Checkpoint"):
    print(f"==== 🔍 TOP-LEVEL KEYS — {name} ====")
    for k in ckpt.keys():
        print(" •", k)
    print()


# ---------------------------------------------------------
# 3) Categorize weights into encoder/decoder/other
# ---------------------------------------------------------
def analyze_state_dict(ckpt, name=""):
    sd = ckpt.get("model_state_dict", {})
    print(f"==== 📦 STATE DICT ANALYSIS ({name}) — {len(sd)} tensors ====\n")

    categories = defaultdict(list)

    for k, v in sd.items():
        if k.startswith("encoder."):
            categories["encoder"].append(k)
        elif "head" in k.lower():
            categories["head"].append(k)
        elif "decoder" in k.lower():
            categories["decoder"].append(k)
        else:
            categories["other"].append(k)

    # Print grouped keys
    for cat, keys in categories.items():
        print(f"--- {cat.upper()} ({len(keys)} keys) ---")
        for k in keys[:15]:
            print("  -", k)
        if len(keys) > 15:
            print(f"  ... +{len(keys)-15} more")
        print()

    return categories


# ---------------------------------------------------------
# 4) Print parameter shapes
# ---------------------------------------------------------
def print_shapes(ckpt, prefix=None, max_items=20):
    sd = ckpt.get("model_state_dict", {})
    print(f"==== 🔢 SHAPES (filter: {prefix}) ====\n")
    c = 0
    for k, v in sd.items():
        if prefix and not k.startswith(prefix):
            continue
        print(f"{k:60} {tuple(v.shape)}")
        c += 1
        if c >= max_items:
            print("... truncated ...\n")
            break


# ---------------------------------------------------------
# 5) Count parameters
# ---------------------------------------------------------
def count_params(ckpt, name=""):
    sd = ckpt.get("model_state_dict", {})
    total = sum(np.prod(v.shape) for v in sd.values())
    print(f"==== 🧮 PARAMETER COUNT — {name} ====")
    print(f"{total:,} parameters.\n")
    return total


# ---------------------------------------------------------
# 6) Extract encoder-only weights
# ---------------------------------------------------------
def extract_encoder(ckpt):
    sd = ckpt.get("model_state_dict", {})
    enc = {k.replace("encoder.", ""): v for k, v in sd.items() if k.startswith("encoder.")}
    print(f"🎯 Extracted {len(enc)} encoder weights.\n")
    return enc


# ---------------------------------------------------------
# 7) Compare two checkpoints in depth
# ---------------------------------------------------------
def compare_checkpoints(ck1, ck2):
    sd1 = ck1.get("model_state_dict", {})
    sd2 = ck2.get("model_state_dict", {})

    keys1 = set(sd1.keys())
    keys2 = set(sd2.keys())

    print("==== 🔍 COMPARISON — Missing Keys ====\n")

    missing_in_2 = sorted(keys1 - keys2)
    missing_in_1 = sorted(keys2 - keys1)

    print(f"Missing in checkpoint2 ({len(missing_in_2)}):")
    for k in missing_in_2[:15]:
        print("  -", k)
    if len(missing_in_2) > 15:
        print(f"  ... +{len(missing_in_2)-15}\n")

    print(f"Missing in checkpoint1 ({len(missing_in_1)}):")
    for k in missing_in_1[:15]:
        print("  -", k)
    if len(missing_in_1) > 15:
        print(f"  ... +{len(missing_in_1)-15}\n")

    print("\n==== 🔄 SHAPE MISMATCHES ====\n")
    for k in sorted(keys1 & keys2):
        if sd1[k].shape != sd2[k].shape:
            print(f"{k:50}  {tuple(sd1[k].shape)} → {tuple(sd2[k].shape)}")

    print()


# ---------------------------------------------------------
# 8) Weight similarity (L2 difference)
# ---------------------------------------------------------
def compute_layer_similarity(ck1, ck2):
    sd1 = ck1.get("model_state_dict", {})
    sd2 = ck2.get("model_state_dict", {})

    print("==== 📉 LAYER SIMILARITY (L2 norm) ====\n")
    overlaps = sorted(set(sd1.keys()) & set(sd2.keys()))

    diffs = []
    for k in overlaps:
        v1 = sd1[k].float().view(-1)
        v2 = sd2[k].float().view(-1)
        diff = torch.norm(v1 - v2).item()
        diffs.append((k, diff))

    diffs_sorted = sorted(diffs, key=lambda x: -x[1])[:30]

    for k, d in diffs_sorted:
        print(f"{k:50}  Δ={d:.4f}")

    print()


# ---------------------------------------------------------
# 9) Plot weight histograms of encoder
# ---------------------------------------------------------
def plot_histograms(ck1, ck2, layer="encoder.pos_embed"):
    sd1 = ck1["model_state_dict"]
    sd2 = ck2["model_state_dict"]

    if layer not in sd1 or layer not in sd2:
        print(f"Layer {layer} not found in both checkpoints.")
        return

    w1 = sd1[layer].cpu().numpy().flatten()
    w2 = sd2[layer].cpu().numpy().flatten()

    plt.figure(figsize=(12,5))
    plt.hist(w1, bins=100, alpha=0.5, label="ckpt1")
    plt.hist(w2, bins=100, alpha=0.5, label="ckpt2")
    plt.title(f"Weight Histogram — {layer}")
    plt.legend()
    plt.show()



# =========================================================
#               ANALYSIS STARTS HERE
# =========================================================

ck1 = load_checkpoint(ckpt1_path)
ck2 = load_checkpoint(ckpt2_path)

print_top_level(ck1, "Virchow Official")
print_top_level(ck2, "Your Fine-tuned Model")

cats1 = analyze_state_dict(ck1, "Virchow Official")
cats2 = analyze_state_dict(ck2, "Your Model")

count_params(ck1, "Virchow Official")
count_params(ck2, "Your Model")

print_shapes(ck1, "encoder.")
print_shapes(ck2, "encoder.")

compare_checkpoints(ck1, ck2)

compute_layer_similarity(ck1, ck2)

# Try comparing pos_embed histograms (often very telling)
plot_histograms(ck1, ck2, "encoder.pos_embed")
# Out:
# 📂 Loading checkpoint: /projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/CellViT-plus-plus/checkpoints/Virchow/CellViT-Virchow-x40-AMP.pth
# ✔ Loaded successfully.
#
# 📂 Loading checkpoint: /projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/ProcessedDataset/v1_40x_area20/patches_cellvit_p128_pannuke/logs_local/2025-11-15T150541_tcga_finetune_128_reheat/checkpoints/model_best.pth
# ✔ Loaded successfully.
#
# ==== 🔍 TOP-LEVEL KEYS — Virchow Official ====
#  • arch
#  • epoch
#  • model_state_dict
#  • config
#  • scaler_state_dict
#
# ==== 🔍 TOP-LEVEL KEYS — Your Fine-tuned Model ====
#  • arch
#  • epoch
#  • model_state_dict
#  • optimizer_state_dict
#  • scheduler_state_dict
#  • best_metric
#  • best_epoch
#  • config
#  • wandb_id
#  • logdir
#  • run_name
#  • scaler_state_dict
#
# ==== 📦 STATE DICT ANALYSIS (Virchow Official) — 743 tensors ====
#
# --- ENCODER (456 keys) ---
#   - encoder.cls_token
#   - encoder.pos_embed
#   - encoder.patch_embed.proj.weight
#   - encoder.patch_embed.proj.bias
#   - encoder.blocks.0.norm1.weight
#   - encoder.blocks.0.norm1.bias
#   - encoder.blocks.0.attn.qkv.weight
#   - encoder.blocks.0.attn.qkv.bias
#   - encoder.blocks.0.attn.proj.weight
#   - encoder.blocks.0.attn.proj.bias
#   - encoder.blocks.0.ls1.gamma
#   - encoder.blocks.0.norm2.weight
#   - encoder.blocks.0.norm2.bias
#   - encoder.blocks.0.mlp.fc1.weight
#   - encoder.blocks.0.mlp.fc1.bias
#   ... +441 more
#
# --- DECODER (239 keys) ---
#   - decoder0.0.block.0.weight
#   - decoder0.0.block.0.bias
#   - decoder0.0.block.1.weight
#   - decoder0.0.block.1.bias
#   - decoder0.0.block.1.running_mean
#   - decoder0.0.block.1.running_var
#   - decoder0.0.block.1.num_batches_tracked
#   - decoder0.1.block.0.weight
#   - decoder0.1.block.0.bias
#   - decoder0.1.block.1.weight
#   - decoder0.1.block.1.bias
#   - decoder0.1.block.1.running_mean
#   - decoder0.1.block.1.running_var
#   - decoder0.1.block.1.num_batches_tracked
#   - decoder1.0.block.0.weight
#   ... +224 more
#
# --- HEAD (48 keys) ---
#   - nuclei_binary_map_decoder.decoder0_header.0.block.0.weight
#   - nuclei_binary_map_decoder.decoder0_header.0.block.0.bias
#   - nuclei_binary_map_decoder.decoder0_header.0.block.1.weight
#   - nuclei_binary_map_decoder.decoder0_header.0.block.1.bias
#   - nuclei_binary_map_decoder.decoder0_header.0.block.1.running_mean
#   - nuclei_binary_map_decoder.decoder0_header.0.block.1.running_var
#   - nuclei_binary_map_decoder.decoder0_header.0.block.1.num_batches_tracked
#   - nuclei_binary_map_decoder.decoder0_header.1.block.0.weight
#   - nuclei_binary_map_decoder.decoder0_header.1.block.0.bias
#   - nuclei_binary_map_decoder.decoder0_header.1.block.1.weight
#   - nuclei_binary_map_decoder.decoder0_header.1.block.1.bias
#   - nuclei_binary_map_decoder.decoder0_header.1.block.1.running_mean
#   - nuclei_binary_map_decoder.decoder0_header.1.block.1.running_var
#   - nuclei_binary_map_decoder.decoder0_header.1.block.1.num_batches_tracked
#   - nuclei_binary_map_decoder.decoder0_header.2.weight
#   ... +33 more
#
# ==== 📦 STATE DICT ANALYSIS (Your Model) — 746 tensors ====
#
# --- ENCODER (457 keys) ---
#   - encoder.pos_embed
#   - encoder.patch_embed.proj.weight
#   - encoder.patch_embed.proj.bias
#   - encoder.blocks.0.norm1.weight
#   - encoder.blocks.0.norm1.bias
#   - encoder.blocks.0.attn.rel_pos_h
#   - encoder.blocks.0.attn.rel_pos_w
#   - encoder.blocks.0.attn.qkv.weight
#   - encoder.blocks.0.attn.qkv.bias
#   - encoder.blocks.0.attn.proj.weight
#   - encoder.blocks.0.attn.proj.bias
#   - encoder.blocks.0.norm2.weight
#   - encoder.blocks.0.norm2.bias
#   - encoder.blocks.0.mlp.lin1.weight
#   - encoder.blocks.0.mlp.lin1.bias
#   ... +442 more
#
# --- DECODER (239 keys) ---
#   - decoder0.0.block.0.weight
#   - decoder0.0.block.0.bias
#   - decoder0.0.block.1.weight
#   - decoder0.0.block.1.bias
#   - decoder0.0.block.1.running_mean
#   - decoder0.0.block.1.running_var
#   - decoder0.0.block.1.num_batches_tracked
#   - decoder0.1.block.0.weight
#   - decoder0.1.block.0.bias
#   - decoder0.1.block.1.weight
#   - decoder0.1.block.1.bias
#   - decoder0.1.block.1.running_mean
#   - decoder0.1.block.1.running_var
#   - decoder0.1.block.1.num_batches_tracked
#   - decoder1.0.block.0.weight
#   ... +224 more
#
# --- HEAD (50 keys) ---
#   - nuclei_binary_map_decoder.decoder0_header.0.block.0.weight
#   - nuclei_binary_map_decoder.decoder0_header.0.block.0.bias
#   - nuclei_binary_map_decoder.decoder0_header.0.block.1.weight
#   - nuclei_binary_map_decoder.decoder0_header.0.block.1.bias
#   - nuclei_binary_map_decoder.decoder0_header.0.block.1.running_mean
#   - nuclei_binary_map_decoder.decoder0_header.0.block.1.running_var
#   - nuclei_binary_map_decoder.decoder0_header.0.block.1.num_batches_tracked
#   - nuclei_binary_map_decoder.decoder0_header.1.block.0.weight
#   - nuclei_binary_map_decoder.decoder0_header.1.block.0.bias
#   - nuclei_binary_map_decoder.decoder0_header.1.block.1.weight
#   - nuclei_binary_map_decoder.decoder0_header.1.block.1.bias
#   - nuclei_binary_map_decoder.decoder0_header.1.block.1.running_mean
#   - nuclei_binary_map_decoder.decoder0_header.1.block.1.running_var
#   - nuclei_binary_map_decoder.decoder0_header.1.block.1.num_batches_tracked
#   - nuclei_binary_map_decoder.decoder0_header.2.weight
#   ... +35 more
#
# ==== 🧮 PARAMETER COUNT — Virchow Official ====
# 693,982,912.0 parameters.
#
# ==== 🧮 PARAMETER COUNT — Your Model ====
# 699,755,694.0 parameters.
#
# ==== 🔢 SHAPES (filter: encoder.) ====
#
# encoder.cls_token                                            (1, 1, 1280)
# encoder.pos_embed                                            (1, 257, 1280)
# encoder.patch_embed.proj.weight                              (1280, 3, 14, 14)
# encoder.patch_embed.proj.bias                                (1280,)
# encoder.blocks.0.norm1.weight                                (1280,)
# encoder.blocks.0.norm1.bias                                  (1280,)
# encoder.blocks.0.attn.qkv.weight                             (3840, 1280)
# encoder.blocks.0.attn.qkv.bias                               (3840,)
# encoder.blocks.0.attn.proj.weight                            (1280, 1280)
# encoder.blocks.0.attn.proj.bias                              (1280,)
# encoder.blocks.0.ls1.gamma                                   (1280,)
# encoder.blocks.0.norm2.weight                                (1280,)
# encoder.blocks.0.norm2.bias                                  (1280,)
# encoder.blocks.0.mlp.fc1.weight                              (6832, 1280)
# encoder.blocks.0.mlp.fc1.bias                                (6832,)
# encoder.blocks.0.mlp.fc2.weight                              (1280, 3416)
# encoder.blocks.0.mlp.fc2.bias                                (1280,)
# encoder.blocks.0.ls2.gamma                                   (1280,)
# encoder.blocks.1.norm1.weight                                (1280,)
# encoder.blocks.1.norm1.bias                                  (1280,)
# ... truncated ...
#
# ==== 🔢 SHAPES (filter: encoder.) ====
#
# encoder.pos_embed                                            (1, 64, 64, 1280)
# encoder.patch_embed.proj.weight                              (1280, 3, 16, 16)
# encoder.patch_embed.proj.bias                                (1280,)
# encoder.blocks.0.norm1.weight                                (1280,)
# encoder.blocks.0.norm1.bias                                  (1280,)
# encoder.blocks.0.attn.rel_pos_h                              (27, 80)
# encoder.blocks.0.attn.rel_pos_w                              (27, 80)
# encoder.blocks.0.attn.qkv.weight                             (3840, 1280)
# encoder.blocks.0.attn.qkv.bias                               (3840,)
# encoder.blocks.0.attn.proj.weight                            (1280, 1280)
# encoder.blocks.0.attn.proj.bias                              (1280,)
# encoder.blocks.0.norm2.weight                                (1280,)
# encoder.blocks.0.norm2.bias                                  (1280,)
# encoder.blocks.0.mlp.lin1.weight                             (5120, 1280)
# encoder.blocks.0.mlp.lin1.bias                               (5120,)
# encoder.blocks.0.mlp.lin2.weight                             (1280, 5120)
# encoder.blocks.0.mlp.lin2.bias                               (1280,)
# encoder.blocks.1.norm1.weight                                (1280,)
# encoder.blocks.1.norm1.bias                                  (1280,)
# encoder.blocks.1.attn.rel_pos_h                              (27, 80)
# ... truncated ...
#
# ==== 🔍 COMPARISON — Missing Keys ====
#
# Missing in checkpoint2 (197):
#   - encoder.blocks.0.ls1.gamma
#   - encoder.blocks.0.ls2.gamma
#   - encoder.blocks.0.mlp.fc1.bias
#   - encoder.blocks.0.mlp.fc1.weight
#   - encoder.blocks.0.mlp.fc2.bias
#   - encoder.blocks.0.mlp.fc2.weight
#   - encoder.blocks.1.ls1.gamma
#   - encoder.blocks.1.ls2.gamma
#   - encoder.blocks.1.mlp.fc1.bias
#   - encoder.blocks.1.mlp.fc1.weight
#   - encoder.blocks.1.mlp.fc2.bias
#   - encoder.blocks.1.mlp.fc2.weight
#   - encoder.blocks.10.ls1.gamma
#   - encoder.blocks.10.ls2.gamma
#   - encoder.blocks.10.mlp.fc1.bias
#   ... +182
#
# Missing in checkpoint1 (200):
#   - classifier_head.bias
#   - classifier_head.weight
#   - encoder.blocks.0.attn.rel_pos_h
#   - encoder.blocks.0.attn.rel_pos_w
#   - encoder.blocks.0.mlp.lin1.bias
#   - encoder.blocks.0.mlp.lin1.weight
#   - encoder.blocks.0.mlp.lin2.bias
#   - encoder.blocks.0.mlp.lin2.weight
#   - encoder.blocks.1.attn.rel_pos_h
#   - encoder.blocks.1.attn.rel_pos_w
#   - encoder.blocks.1.mlp.lin1.bias
#   - encoder.blocks.1.mlp.lin1.weight
#   - encoder.blocks.1.mlp.lin2.bias
#   - encoder.blocks.1.mlp.lin2.weight
#   - encoder.blocks.10.attn.rel_pos_h
#   ... +185
#
#
# ==== 🔄 SHAPE MISMATCHES ====
#
# encoder.patch_embed.proj.weight                     (1280, 3, 14, 14) → (1280, 3, 16, 16)
# encoder.pos_embed                                   (1, 257, 1280) → (1, 64, 64, 1280)
#
# ==== 📉 LAYER SIMILARITY (L2 norm) ====
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 207
#     203 print_shapes(ck2, "encoder.")
#     205 compare_checkpoints(ck1, ck2)
# --> 207 compute_layer_similarity(ck1, ck2)
#     209 # Try comparing pos_embed histograms (often very telling)
#     210 plot_histograms(ck1, ck2, "encoder.pos_embed")
#
# Cell In[3], line 152, in compute_layer_similarity(ck1, ck2)
#     150     v1 = sd1[k].float().view(-1)
#     151     v2 = sd2[k].float().view(-1)
# --> 152     diff = torch.norm(v1 - v2).item()
#     153     diffs.append((k, diff))
#     155 diffs_sorted = sorted(diffs, key=lambda x: -x[1])[:30]
#
# RuntimeError: The size of tensor a (752640) must match the size of tensor b (983040) at non-singleton dimension 0

# %%
ckpt1_path = "/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/CellViT-plus-plus/checkpoints/SAM/encoder_only_CellViT-SAM-H-x40-AMP.pth"
# =========================================================
#               ANALYSIS STARTS HERE
# =========================================================

ck1 = load_checkpoint(ckpt1_path)
ck2 = load_checkpoint(ckpt2_path)

print_top_level(ck1, "Virchow Official")
print_top_level(ck2, "Your Fine-tuned Model")

cats1 = analyze_state_dict(ck1, "Virchow Official")
cats2 = analyze_state_dict(ck2, "Your Model")

count_params(ck1, "Virchow Official")
count_params(ck2, "Your Model")

print_shapes(ck1, "encoder.")
print_shapes(ck2, "encoder.")

compare_checkpoints(ck1, ck2)

compute_layer_similarity(ck1, ck2)

# Try comparing pos_embed histograms (often very telling)
plot_histograms(ck1, ck2, "encoder.pos_embed")
# Out:
# 📂 Loading checkpoint: /projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/CellViT-plus-plus/checkpoints/SAM/encoder_only_CellViT-SAM-H-x40-AMP.pth
# ✔ Loaded successfully.
#
# 📂 Loading checkpoint: /projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/ProcessedDataset/v1_40x_area20/patches_cellvit_p128_pannuke/logs_local/2025-11-15T150541_tcga_finetune_128_reheat/checkpoints/model_best.pth
# ✔ Loaded successfully.
#
# ==== 🔍 TOP-LEVEL KEYS — Virchow Official ====
#  • pos_embed
#  • patch_embed.proj.weight
#  • patch_embed.proj.bias
#  • blocks.0.norm1.weight
#  • blocks.0.norm1.bias
#  • blocks.0.attn.rel_pos_h
#  • blocks.0.attn.rel_pos_w
#  • blocks.0.attn.qkv.weight
#  • blocks.0.attn.qkv.bias
#  • blocks.0.attn.proj.weight
#  • blocks.0.attn.proj.bias
#  • blocks.0.norm2.weight
#  • blocks.30.mlp.lin2.weight
#  • blocks.30.mlp.lin2.bias
#  • blocks.31.norm1.weight
#  • blocks.31.norm1.bias
#  • blocks.31.attn.rel_pos_h
#  • blocks.31.attn.rel_pos_w
#  • blocks.31.attn.qkv.weight
#  • blocks.31.attn.qkv.bias
#  • blocks.31.attn.proj.weight
#  • blocks.31.attn.proj.bias
#  • blocks.31.norm2.weight
#  • blocks.31.norm2.bias
#  • blocks.31.mlp.lin1.weight
#  • blocks.31.mlp.lin1.bias
#  • blocks.31.mlp.lin2.weight
#  • blocks.31.mlp.lin2.bias
#  • neck.0.weight
#  • neck.1.weight
#  • neck.1.bias
#  • neck.2.weight
#  • neck.3.weight
#  • neck.3.bias
#
# ==== 🔍 TOP-LEVEL KEYS — Your Fine-tuned Model ====
#  • arch
#  • epoch
#  • model_state_dict
#  • optimizer_state_dict
#  • scheduler_state_dict
#  • best_metric
#  • best_epoch
#  • config
#  • wandb_id
#  • logdir
#  • run_name
#  • scaler_state_dict
#
# ==== 📦 STATE DICT ANALYSIS (Virchow Official) — 0 tensors ====
#
# ==== 📦 STATE DICT ANALYSIS (Your Model) — 746 tensors ====
#
# --- ENCODER (457 keys) ---
#   - encoder.pos_embed
#   - encoder.patch_embed.proj.weight
#   - encoder.patch_embed.proj.bias
#   - encoder.blocks.0.norm1.weight
#   - encoder.blocks.0.norm1.bias
#   - encoder.blocks.0.attn.rel_pos_h
#   - encoder.blocks.0.attn.rel_pos_w
#   - encoder.blocks.0.attn.qkv.weight
#   - encoder.blocks.0.attn.qkv.bias
#   - encoder.blocks.0.attn.proj.weight
#   - encoder.blocks.0.attn.proj.bias
#   - encoder.blocks.0.norm2.weight
#   - encoder.blocks.0.norm2.bias
#   - encoder.blocks.0.mlp.lin1.weight
#   - encoder.blocks.0.mlp.lin1.bias
#   ... +442 more
#
# --- DECODER (239 keys) ---
#   - decoder0.0.block.0.weight
#   - decoder0.0.block.0.bias
#   - decoder0.0.block.1.weight
#   - decoder0.0.block.1.bias
#   - decoder0.0.block.1.running_mean
#   - decoder0.0.block.1.running_var
#   - decoder0.0.block.1.num_batches_tracked
#   - decoder0.1.block.0.weight
#   - decoder0.1.block.0.bias
#   - decoder0.1.block.1.weight
#   - decoder0.1.block.1.bias
#   - decoder0.1.block.1.running_mean
#   - decoder0.1.block.1.running_var
#   - decoder0.1.block.1.num_batches_tracked
#   - decoder1.0.block.0.weight
#   ... +224 more
#
# --- HEAD (50 keys) ---
#   - nuclei_binary_map_decoder.decoder0_header.0.block.0.weight
#   - nuclei_binary_map_decoder.decoder0_header.0.block.0.bias
#   - nuclei_binary_map_decoder.decoder0_header.0.block.1.weight
#   - nuclei_binary_map_decoder.decoder0_header.0.block.1.bias
#   - nuclei_binary_map_decoder.decoder0_header.0.block.1.running_mean
#   - nuclei_binary_map_decoder.decoder0_header.0.block.1.running_var
#   - nuclei_binary_map_decoder.decoder0_header.0.block.1.num_batches_tracked
#   - nuclei_binary_map_decoder.decoder0_header.1.block.0.weight
#   - nuclei_binary_map_decoder.decoder0_header.1.block.0.bias
#   - nuclei_binary_map_decoder.decoder0_header.1.block.1.weight
#   - nuclei_binary_map_decoder.decoder0_header.1.block.1.bias
#   - nuclei_binary_map_decoder.decoder0_header.1.block.1.running_mean
#   - nuclei_binary_map_decoder.decoder0_header.1.block.1.running_var
#   - nuclei_binary_map_decoder.decoder0_header.1.block.1.num_batches_tracked
#   - nuclei_binary_map_decoder.decoder0_header.2.weight
#   ... +35 more
#
# ==== 🧮 PARAMETER COUNT — Virchow Official ====
# 0 parameters.
#
# ==== 🧮 PARAMETER COUNT — Your Model ====
# 699,755,694.0 parameters.
#
# ==== 🔢 SHAPES (filter: encoder.) ====
#
# ==== 🔢 SHAPES (filter: encoder.) ====
#
# encoder.pos_embed                                            (1, 64, 64, 1280)
# encoder.patch_embed.proj.weight                              (1280, 3, 16, 16)
# encoder.patch_embed.proj.bias                                (1280,)
# encoder.blocks.0.norm1.weight                                (1280,)
# encoder.blocks.0.norm1.bias                                  (1280,)
# encoder.blocks.0.attn.rel_pos_h                              (27, 80)
# encoder.blocks.0.attn.rel_pos_w                              (27, 80)
# encoder.blocks.0.attn.qkv.weight                             (3840, 1280)
# encoder.blocks.0.attn.qkv.bias                               (3840,)
# encoder.blocks.0.attn.proj.weight                            (1280, 1280)
# encoder.blocks.0.attn.proj.bias                              (1280,)
# encoder.blocks.0.norm2.weight                                (1280,)
# encoder.blocks.0.norm2.bias                                  (1280,)
# encoder.blocks.0.mlp.lin1.weight                             (5120, 1280)
# encoder.blocks.0.mlp.lin1.bias                               (5120,)
# encoder.blocks.0.mlp.lin2.weight                             (1280, 5120)
# encoder.blocks.0.mlp.lin2.bias                               (1280,)
# encoder.blocks.1.norm1.weight                                (1280,)
# encoder.blocks.1.norm1.bias                                  (1280,)
# encoder.blocks.1.attn.rel_pos_h                              (27, 80)
# ... truncated ...
#
# ==== 🔍 COMPARISON — Missing Keys ====
#
# Missing in checkpoint2 (0):
# Missing in checkpoint1 (746):
#   - classifier_head.bias
#   - classifier_head.weight
#   - decoder0.0.block.0.bias
#   - decoder0.0.block.0.weight
#   - decoder0.0.block.1.bias
#   - decoder0.0.block.1.num_batches_tracked
#   - decoder0.0.block.1.running_mean
#   - decoder0.0.block.1.running_var
#   - decoder0.0.block.1.weight
#   - decoder0.1.block.0.bias
#   - decoder0.1.block.0.weight
#   - decoder0.1.block.1.bias
#   - decoder0.1.block.1.num_batches_tracked
#   - decoder0.1.block.1.running_mean
#   - decoder0.1.block.1.running_var
#   ... +731
#
#
# ==== 🔄 SHAPE MISMATCHES ====
#
#
# ==== 📉 LAYER SIMILARITY (L2 norm) ====
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 26
#      23 compute_layer_similarity(ck1, ck2)
#      25 # Try comparing pos_embed histograms (often very telling)
# ---> 26 plot_histograms(ck1, ck2, "encoder.pos_embed")
#
# Cell In[3], line 167, in plot_histograms(ck1, ck2, layer)
#     166 def plot_histograms(ck1, ck2, layer="encoder.pos_embed"):
# --> 167     sd1 = ck1["model_state_dict"]
#     168     sd2 = ck2["model_state_dict"]
#     170     if layer not in sd1 or layer not in sd2:
#
# KeyError: 'model_state_dict'

# %% [markdown]
# ## Extract encoder keys from checkpoint!

# %%
import torch
from pathlib import Path

def extract_encoder_only(root_dir, checkpoint_name):
    root = Path(root_dir)
    input_path = root / checkpoint_name

    if not input_path.exists():
        raise FileNotFoundError(f"❌ Checkpoint not found:\n{input_path}")

    ckpt = torch.load(input_path, map_location="cpu")

    if "model_state_dict" not in ckpt:
        raise ValueError("❌ Checkpoint does not contain model_state_dict!")

    full_sd = ckpt["model_state_dict"]

    # ---- Extract encoder.* keys ----
    encoder_only = {}
    for k, v in full_sd.items():
        if k.startswith("encoder."):
            new_k = k.replace("encoder.", "")   # SAME FORMAT CellViT expects
            encoder_only[new_k] = v

    output_path = root / f"encoder_only_{checkpoint_name}"

    # Save ONLY the pure encoder state dict
    torch.save(encoder_only, output_path)

    print("====================================")
    print(f"📦 Input checkpoint : {input_path}")
    print(f"🔑 Extracted keys   : {len(encoder_only)}")
    print(f"💾 Saved encoder to : {output_path}")
    print("====================================")

    return output_path

# %%
root_dir = "/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/CellViT-plus-plus/checkpoints/Virchow"
checkpoint_name= "CellViT-Virchow-x40-AMP.pth"


extract_encoder_only(root_dir, checkpoint_name)
# Out:
# ====================================
# 📦 Input checkpoint : /projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/CellViT-plus-plus/checkpoints/Virchow/CellViT-Virchow-x40-AMP.pth
# 🔑 Extracted keys   : 456
# 💾 Saved encoder to : /projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/CellViT-plus-plus/checkpoints/Virchow/encoder_only_CellViT-Virchow-x40-AMP.pth
# ====================================
# PosixPath('/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/CellViT-plus-plus/checkpoints/Virchow/encoder_only_CellViT-Virchow-x40-AMP.pth')

# %% [markdown]
# ## Analyze Cellvit Pipeline Checkpoints

# %%
import torch

ckpt_path = "/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/ProcessedDataset/v1_40x_area20_2/patches_cellvit_p256_pannuke/logs_local_berk/2025-12-05T191217_First film try same with patch size 256/checkpoints/model_best.pth" 
ckpt = torch.load(ckpt_path, map_location="cpu", weights_only=False)

print("Top-level keys:", ckpt.keys())
# Out:
# Top-level keys: dict_keys(['arch', 'epoch', 'model_state_dict', 'optimizer_state_dict', 'scheduler_state_dict', 'best_metric', 'best_epoch', 'config', 'wandb_id', 'logdir', 'run_name', 'scaler_state_dict'])

# %% [markdown]
# ## Checkpoint config

# %%
print(ckpt["best_metric"])
print(ckpt["best_epoch"])

print("\n=== CONFIG ===")
for k,v in ckpt["config"].items():
    print(k, ":", v)
# Out:
# 0.688046353861404
# 77
#
# === CONFIG ===
# random_seed : 19
# gpu : 0
# data.dataset : PanNuke
# data.dataset_path : /projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/ProcessedDataset/v1_40x_area20_2/patches_cellvit_p256_pannuke
# data.input_shape : 256
# data.train_folds : [0]
# data.val_folds : [1]
# data.num_nuclei_classes : 6
# data.num_tissue_classes : 1
# dataloader.train.num_workers : 6
# dataloader.train.pin_memory : True
# dataloader.train.persistent_workers : True
# dataloader.train.drop_last : True
# dataloader.val.num_workers : 4
# dataloader.val.pin_memory : True
# dataloader.val.persistent_workers : True
# dataloader.val.drop_last : True
# model.backbone : sam-h-rosie-film
# model.pretrained_encoder : /projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/CellViT-plus-plus/checkpoints/SAM/encoder_only_CellViT-SAM-H-x40-AMP.pth
# model.rosie_hidden_dim : 256
# fusion.freeze_cellvit : True
# fusion.freeze_rosie : True
# training.drop_rate : 0
# training.attn_drop_rate : 0.1
# training.drop_path_rate : 0.1
# training.batch_size : 2
# training.epochs : 80
# training.optimizer : AdamW
# training.early_stopping_patience : 80
# training.scheduler.scheduler_type : cosine
# training.scheduler.warmup_epochs : 2
# training.optimizer_hyperparameter.lr : 3e-05
# training.unfreeze_epoch : 0
# training.sampling_strategy : random
# training.eval_every : 1
# training.mixed_precision : True
# training.resume : True
# just_load_model : False
# loss.nuclei_type_map.bce.loss_fn : xentropy_loss
# loss.nuclei_type_map.bce.weight : 0.5
# loss.nuclei_type_map.dice.loss_fn : dice_loss
# loss.nuclei_type_map.dice.weight : 0.2
# loss.nuclei_type_map.mcfocaltverskyloss.loss_fn : MCFocalTverskyLoss
# loss.nuclei_type_map.mcfocaltverskyloss.weight : 0.5
# loss.nuclei_type_map.mcfocaltverskyloss.args.num_classes : 6
# transformations.randomrotate90.p : 0.5
# transformations.horizontalflip.p : 0.5
# transformations.verticalflip.p : 0.5
# transformations.downscale.p : 0.15
# transformations.downscale.scale : 0.5
# transformations.blur.p : 0.2
# transformations.blur.blur_limit : 10
# transformations.gaussnoise.p : 0.25
# transformations.gaussnoise.var_limit : 50
# transformations.colorjitter.p : 0.2
# transformations.colorjitter.scale_setting : 0.25
# transformations.colorjitter.scale_color : 0.1
# transformations.superpixels.p : 0.1
# transformations.zoomblur.p : 0.1
# transformations.randomsizedcrop.p : 0.1
# transformations.elastictransform.p : 0.2
# transformations.normalize.mean : [0.5, 0.5, 0.5]
# transformations.normalize.std : [0.5, 0.5, 0.5]
# eval_checkpoint : None
# dataset_config.name : TCGA
# dataset_config.magnification : 40
# dataset_config.patch_size : 256
# dataset_config.num_classes : 1
# dataset_config.stain_normalized : False
# dataset_config.description : TCGA Lung patches prepared for CellViT fine-tuning
# dataset_config.tissue_types.Lung : 0
# dataset_config.nuclei_types.background : 0
# dataset_config.nuclei_types.epithelial : 1
# dataset_config.nuclei_types.lymphocyte : 2
# dataset_config.nuclei_types.macrophage : 3
# dataset_config.nuclei_types.neutrophil : 4
# dataset_config.nuclei_types.other : 5
# logging.project : samh-rosie-film
# logging.mode : online
# logging.wandb_dir : /projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/ProcessedDataset/v1_40x_area20_2/patches_cellvit_p256_pannuke/logs_local_berk
# logging.log_dir : /projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/ProcessedDataset/v1_40x_area20_2/patches_cellvit_p256_pannuke/logs_local_berk/2025-12-05T191217_First film try same with patch size 256
# logging.notes : First film try rosie and samh early fusion
# logging.log_comment : First film try same with patch size 256
# logging.level : debug
# logging.log_images : True
# logging.run_id : k68ttwdk
# logging.wandb_file : k68ttwdk
# run_sweep : False
# agent : None

# %% [markdown]
# ## Connect to wandb to get the metrics

# %%
import wandb

run = wandb.Api().run("samh-rosie-film/k68ttwdk")

# Print available summary metrics
print("=== SUMMARY METRICS ===")
for k,v in run.summary.items():
    print(k, ":", v)

# Print history keys
print("\n=== HISTORY KEYS ===")
history = run.history(samples=5)
print(history.columns)
# Out:
# === SUMMARY METRICS ===
# Best-Epoch : 77
# Best-Metric : 0.688046353861404
# Binary-Cell-Dice-Mean/Train : 0.9167978673708213
# Binary-Cell-Dice-Mean/Validation : 0.8097800939704813
# Binary-Cell-Jacard-Mean/Train : 0.8507988192556825
# Binary-Cell-Jacard-Mean/Validation : 0.6973950930617072
# Example-Predictions/Train : {'_type': 'image-file', 'format': 'png', 'height': 600, 'path': 'media/images/Example-Predictions/Train_80_5fffc55ef50e9ce88a8e.png', 'sha256': '5fffc55ef50e9ce88a8e86d5911921760d684193b3b21d3d9dda4ec9d5898443', 'size': 255716, 'width': 900}
# Example-Predictions/Validation : {'_type': 'image-file', 'format': 'png', 'height': 1200, 'path': 'media/images/Example-Predictions/Validation_80_da284a3d9f407275d90e.png', 'sha256': 'da284a3d9f407275d90eb00bec925ed9f0082f437f194f1a278085d4b9ac745f', 'size': 1160824, 'width': 900}
# Learning-Rate/Learning-Rate : 1.0007709637592772e-05
# Loss/Train : 3.1750598628165196
# Loss/Validation : 3.4648467302322388
# Tissue-Multiclass-Accuracy/Train : 1
# Tissue-Multiclass-Accuracy/Validation : 1
# _runtime : 10865.860516786575
# _step : 80
# _timestamp : 1764990804.008916
# _wandb : {'runtime': 10881}
# bPQ/Validation : 0.6673502536292482
# epithelial-PQ/Validation : 0.6550591521165006
# hv_map_mse/Train : 0.012887109968632892
# hv_map_mse/Validation : 0.02398407831788063
# hv_map_msge/Train : 0.15608352200358375
# hv_map_msge/Validation : 0.21054454892873764
# lung-Dice/Validation : 0.8097800939704813
# lung-Jaccard/Validation : 0.6973950930617072
# lung-bPQ/Validation : 0.6673502536292482
# lung-mPQ/Validation : 0.5865822873656977
# lymphocyte-PQ/Validation : 0.5600422774354358
# mPQ/Validation : 0.5865822873656977
# macrophage-PQ/Validation : 0.36575954136026895
# neutrophil-PQ/Validation : 0.28911017717983434
# nuclei_binary_map_bce/Train : 0.07567855050550869
# nuclei_binary_map_bce/Validation : 0.25757379829883575
# nuclei_binary_map_dice/Train : 0.11292885791485452
# nuclei_binary_map_dice/Validation : 0.2154303789138794
# nuclei_type_map_bce/Train : 0.09235379686848756
# nuclei_type_map_bce/Validation : 0.3962437957525254
# nuclei_type_map_dice/Train : 1.5081419360664214
# nuclei_type_map_dice/Validation : 1.1957089304924011
# nuclei_type_map_mcfocaltverskyloss/Train : 4.939353057164658
# nuclei_type_map_mcfocaltverskyloss/Validation : 4.640100479125977
# other-PQ/Validation : NaN
# tissue_types_ce/Train : 0
# tissue_types_ce/Validation : 0
#
# === HISTORY KEYS ===
# Index(['hv_map_msge/Train', 'lung-bPQ/Validation', 'Loss/Train',
#        'lung-mPQ/Validation', 'Example-Predictions/Validation',
#        'Learning-Rate/Learning-Rate', 'nuclei_binary_map_dice/Validation',
#        'nuclei_binary_map_dice/Train', 'macrophage-PQ/Validation',
#        'nuclei_binary_map_bce/Validation', 'epithelial-PQ/Validation',
#        'bPQ/Validation', 'Loss/Validation',
#        'Tissue-Multiclass-Accuracy/Validation', 'nuclei_binary_map_bce/Train',
#        '_runtime', 'nuclei_type_map_mcfocaltverskyloss/Validation',
#        'hv_map_mse/Train', 'Binary-Cell-Jacard-Mean/Train',
#        'nuclei_type_map_mcfocaltverskyloss/Train',
#        'nuclei_type_map_dice/Validation', 'Binary-Cell-Dice-Mean/Validation',
#        'other-PQ/Validation', 'hv_map_msge/Validation',
#        'lymphocyte-PQ/Validation', 'nuclei_type_map_bce/Train',
#        'Binary-Cell-Dice-Mean/Train', '_timestamp',
#        'nuclei_type_map_bce/Validation', 'Tissue-Multiclass-Accuracy/Train',
#        '_step', 'Binary-Cell-Jacard-Mean/Validation',
#        'Example-Predictions/Train', 'hv_map_mse/Validation', 'mPQ/Validation',
#        'lung-Jaccard/Validation', 'neutrophil-PQ/Validation',
#        'tissue_types_ce/Train', 'lung-Dice/Validation',
#        'nuclei_type_map_dice/Train', 'tissue_types_ce/Validation'],
#       dtype='object')

# %%
hist = run.history()

epoch_77 = hist[hist["_step"] == 77]
epoch_77
# Out:
#     hv_map_msge/Train  lung-bPQ/Validation  Loss/Train  lung-mPQ/Validation  \
# 76           0.161226             0.683074    3.188467             0.601959
#
#                        Example-Predictions/Validation  \
# 76  {'size': 762529, 'height': 1200, 'width': 900,...
#
#     Learning-Rate/Learning-Rate  nuclei_binary_map_dice/Validation  \
# 76                      0.00001                           0.215248
#
#     nuclei_binary_map_dice/Train  macrophage-PQ/Validation  \
# 76                      0.117796                  0.424398
#
#     nuclei_binary_map_bce/Validation  ...  Binary-Cell-Jacard-Mean/Validation  \
# 76                          0.252089  ...                            0.708908
#
#                             Example-Predictions/Train  hv_map_mse/Validation  \
# 76  {'size': 313614, 'height': 600, 'width': 900, ...               0.024353
#
#     mPQ/Validation  lung-Jaccard/Validation  neutrophil-PQ/Validation  \
# 76        0.601959                 0.708908                  0.420952
#
#     tissue_types_ce/Train  lung-Dice/Validation  nuclei_type_map_dice/Train  \
# 76                      0              0.819427                    1.500885
#
#     tissue_types_ce/Validation
# 76                           0
#
# [1 rows x 41 columns]
