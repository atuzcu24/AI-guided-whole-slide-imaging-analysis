# %% [markdown]
# # Imports & Setup

# %%
import torch
import wandb
import pandas as pd
from pathlib import Path

# %% [markdown]
# ## Helper to inspect checkpoint

# %%
def load_checkpoint_info(ckpt_path):
    ckpt = torch.load(ckpt_path, map_location="cpu", weights_only=False)
    cfg = ckpt["config"]

    return {
        "path": ckpt_path,
        "file": Path(ckpt_path).name,
        "run_id": cfg["logging.run_id"],
        "project": cfg["logging.project"],
        "best_epoch": ckpt["best_epoch"],
        "best_metric": ckpt["best_metric"],
    }

# %% [markdown]
# ## Get W&B metrics for a given run and epoch

# %%
def extract_metrics_from_wandb(run_id, project, best_epoch):
    api = wandb.Api()
    run = api.run(f"{project}/{run_id}")

    hist = run.history()  # full history
    row = hist[hist["_step"] == best_epoch]

    if len(row) == 0:
        print(f"No row found for epoch {best_epoch}")
        return None

    # Take the first (and only) matching row
    row = row.iloc[0].to_dict()
    return row

# %% [markdown]
# # Metrics we want in the comparison table

# %%
METRICS_OF_INTEREST = [
    "Binary-Cell-Dice-Mean/Validation",
    "Binary-Cell-Jacard-Mean/Validation",
    "mPQ/Validation",
    "bPQ/Validation",
    "hv_map_mse/Validation",
    "hv_map_msge/Validation",
]

# %% [markdown]
# ## Compare Checkpoints and Create a Df

# %%
def compare_checkpoints(
    configs,
    metrics=METRICS_OF_INTEREST,
    show_best_epoch=False,
    float_precision=4
):
    rows = []

    for cfg_entry in configs:
        ckpt_path = cfg_entry["path"]
        name = cfg_entry.get("name", Path(ckpt_path).stem)
        patch_size = cfg_entry.get("patch_size", None)

        info = load_checkpoint_info(ckpt_path)

        metrics_row = extract_metrics_from_wandb(
            run_id=info["run_id"],
            project=info["project"],
            best_epoch=info["best_epoch"],
        )

        row_data = {
            "name": name,
            #"checkpoint": info["file"],
            "patch_size": patch_size,
            "best_metric(IoU)": info["best_metric"],
        }

        if show_best_epoch:
            row_data["best_epoch"] = info["best_epoch"]

        for m in metrics:
            row_data[m] = metrics_row.get(m, None)

        rows.append(row_data)

    df = pd.DataFrame(rows)

    # Round floats
    df = df.round(float_precision)

    return df

# %%
checkpoint_paths = [
    #"/path/to/cellvit128.ckpt",
]

checkpoint_configs = [
    {
        "path":  "/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/ProcessedDataset/v1_40x_area20_2/patches_cellvit_p128_pannuke/logs_local/2025-12-03T180258_tcga_finetune_128/checkpoints/model_best.pth",
        "name": "SamH-256",
        "patch_size": 256,
    },
    {
        "path":"/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/ProcessedDataset/v1_40x_area20_2/patches_cellvit_p256_pannuke/logs_local_berk/2025-12-05T191217_First film try same with patch size 256/checkpoints/model_best.pth",
        "name": "SamH-Rosie-FiLM-256",
        "patch_size": 256,
    },
    {
        "path":"/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/ProcessedDataset/v1_40x_area20_2/patches_cellvit_p256_pannuke/logs_local_virchow/2025-12-06T223702_tcga_finetune_256_virchow/checkpoints/model_best.pth",
        "name": "Virchow-256",
        "patch_size": 256,
    },
    {
        "path":"/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/ProcessedDataset/v1_40x_area20_2/patches_cellvit_p256_pannuke/logs_local_virchow_film/2025-12-06T232801_First film try same with patch size 256/checkpoints/model_best.pth",
        "name": "Virchow-Rosie-FiLM-256",
        "patch_size": 256,
    },
    {
        "path":  "/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/ProcessedDataset/v1_40x_area20_2/patches_cellvit_p128_pannuke/logs_local/2025-12-03T180258_tcga_finetune_128/checkpoints/model_best.pth",
        "name": "SamH-128",
        "patch_size": 128,
    },
    {
        "path": "/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/ProcessedDataset/v1_40x_area20_2/patches_cellvit_p128_pannuke/logs_local/2025-12-04T002122_First film try/checkpoints/model_best.pth",
        "name": "SamH-Rosie-FiLM-128",
        "patch_size": 128,
    },
    
]

"""{
        "path": ,
        "name": "CellViT-256",
        "patch_size": 256,
    },""" #TODO Add this part



df = compare_checkpoints(
    configs=checkpoint_configs,
    metrics=METRICS_OF_INTEREST,
    show_best_epoch=False,
    float_precision=3,
)

df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /projectnb/batmanlab/zu55518/.conda/envs/cellvit_env/lib/python3.10/site-packages/wandb/apis/normalize.py:41, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      40 try:
# ---> 41     return func(*args, **kwargs)
#      42 except requests.HTTPError as error:
#
# File /projectnb/batmanlab/zu55518/.conda/envs/cellvit_env/lib/python3.10/site-packages/wandb/apis/public.py:851, in Api.run(self, path)
#     850 if not self._runs.get(path):
# --> 851     self._runs[path] = Run(self.client, entity, project, run_id)
#     852 return self._runs[path]
#
# File /projectnb/batmanlab/zu55518/.conda/envs/cellvit_env/lib/python3.10/site-packages/wandb/apis/public.py:1695, in Run.__init__(self, client, entity, project, run_id, attrs, include_sweeps)
#    1693 self._state = _attrs.get("state", "not found")
# -> 1695 self.load(force=not _attrs)
#
# File /projectnb/batmanlab/zu55518/.conda/envs/cellvit_env/lib/python3.10/site-packages/wandb/apis/public.py:1799, in Run.load(self, force)
#    1794 if (
#    1795     response is None
#    1796     or response.get("project") is None
#    1797     or response["project"].get("run") is None
#    1798 ):
# -> 1799     raise ValueError("Could not find run %s" % self)
#    1800 self._attrs = response["project"]["run"]
#
# ValueError: Could not find run <Run zu55518-boston-university/CellViT_segmentation_128_2/t08un3tk (not found)>
#
# During handling of the above exception, another exception occurred:
#
# CommError                                 Traceback (most recent call last)
# Cell In[11], line 46
#       5 checkpoint_configs = [
#       6     {
#       7         "path":  "/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/ProcessedDataset/v1_40x_area20_2/patches_cellvit_p128_pannuke/logs_local/2025-12-03T180258_tcga_finetune_128/checkpoints/model_best.pth",
#    (...)
#      36
#      37 ]
#      39 """{
#      40         "path": ,
#      41         "name": "CellViT-256",
#      42         "patch_size": 256,
#      43     },""" #TODO Add this part
# ---> 46 df = compare_checkpoints(
#      47     configs=checkpoint_configs,
#      48     metrics=METRICS_OF_INTEREST,
#      49     show_best_epoch=False,
#      50     float_precision=3,
#      51 )
#      53 df
#
# Cell In[6], line 16, in compare_checkpoints(configs, metrics, show_best_epoch, float_precision)
#      12 patch_size = cfg_entry.get("patch_size", None)
#      14 info = load_checkpoint_info(ckpt_path)
# ---> 16 metrics_row = extract_metrics_from_wandb(
#      17     run_id=info["run_id"],
#      18     project=info["project"],
#      19     best_epoch=info["best_epoch"],
#      20 )
#      22 row_data = {
#      23     "name": name,
#      24     #"checkpoint": info["file"],
#      25     "patch_size": patch_size,
#      26     "best_metric(IoU)": info["best_metric"],
#      27 }
#      29 if show_best_epoch:
#
# Cell In[4], line 3, in extract_metrics_from_wandb(run_id, project, best_epoch)
#       1 def extract_metrics_from_wandb(run_id, project, best_epoch):
#       2     api = wandb.Api()
# ----> 3     run = api.run(f"{project}/{run_id}")
#       5     hist = run.history()  # full history
#       6     row = hist[hist["_step"] == best_epoch]
#
# File /projectnb/batmanlab/zu55518/.conda/envs/cellvit_env/lib/python3.10/site-packages/wandb/apis/normalize.py:87, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      85     raise
#      86 else:
# ---> 87     raise CommError(message, err).with_traceback(sys.exc_info()[2])
#
# File /projectnb/batmanlab/zu55518/.conda/envs/cellvit_env/lib/python3.10/site-packages/wandb/apis/normalize.py:41, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      39 message = "Whoa, you found a bug."
#      40 try:
# ---> 41     return func(*args, **kwargs)
#      42 except requests.HTTPError as error:
#      43     errors = parse_backend_error_messages(error.response)
#
# File /projectnb/batmanlab/zu55518/.conda/envs/cellvit_env/lib/python3.10/site-packages/wandb/apis/public.py:851, in Api.run(self, path)
#     849 entity, project, run_id = self._parse_path(path)
#     850 if not self._runs.get(path):
# --> 851     self._runs[path] = Run(self.client, entity, project, run_id)
#     852 return self._runs[path]
#
# File /projectnb/batmanlab/zu55518/.conda/envs/cellvit_env/lib/python3.10/site-packages/wandb/apis/public.py:1695, in Run.__init__(self, client, entity, project, run_id, attrs, include_sweeps)
#    1692 self._summary = None
#    1693 self._state = _attrs.get("state", "not found")
# -> 1695 self.load(force=not _attrs)
#
# File /projectnb/batmanlab/zu55518/.conda/envs/cellvit_env/lib/python3.10/site-packages/wandb/apis/public.py:1799, in Run.load(self, force)
#    1793 response = self._exec(query)
#    1794 if (
#    1795     response is None
#    1796     or response.get("project") is None
#    1797     or response["project"].get("run") is None
#    1798 ):
# -> 1799     raise ValueError("Could not find run %s" % self)
#    1800 self._attrs = response["project"]["run"]
#    1801 self._state = self._attrs["state"]
#
# CommError: Could not find run <Run zu55518-boston-university/CellViT_segmentation_128_2/t08un3tk (not found)>

# %%
checkpoint_configs = [
    {
        "path":  "/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/Docker/checkpoints/lora_rank8.pth",
        "name": "lora_8",
        "patch_size": 256,
    },
    
    
]

df = compare_checkpoints(
    configs=checkpoint_configs,
    metrics=METRICS_OF_INTEREST,
    show_best_epoch=False,
    float_precision=3,
)

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 11
#       1 checkpoint_configs = [
#       2     {
#       3         "path":  "/projectnb/ec500kb/projects/Fall_2025_Projects/Project_2/AI-guided-whole-slide-imaging-analysis/AI-GUIDED-CLEAN/Docker/checkpoints/lora_rank8.pth",
#    (...)
#       8
#       9 ]
# ---> 11 df = compare_checkpoints(
#      12     configs=checkpoint_configs,
#      13     metrics=METRICS_OF_INTEREST,
#      14     show_best_epoch=False,
#      15     float_precision=3,
#      16 )
#      18 df
#
# Cell In[7], line 14, in compare_checkpoints(configs, metrics, show_best_epoch, float_precision)
#      11 name = cfg_entry.get("name", Path(ckpt_path).stem)
#      12 patch_size = cfg_entry.get("patch_size", None)
# ---> 14 info = load_checkpoint_info(ckpt_path)
#      16 metrics_row = extract_metrics_from_wandb(
#      17     run_id=info["run_id"],
#      18     project=info["project"],
#      19     best_epoch=info["best_epoch"],
#      20 )
#      22 row_data = {
#      23     "name": name,
#      24     #"checkpoint": info["file"],
#      25     "patch_size": patch_size,
#      26     "best_metric(IoU)": info["best_metric"],
#      27 }
#
# Cell In[2], line 3, in load_checkpoint_info(ckpt_path)
#       1 def load_checkpoint_info(ckpt_path):
#       2     ckpt = torch.load(ckpt_path, map_location="cpu", weights_only=False)
# ----> 3     cfg = ckpt["config"]
#       5     return {
#       6         "path": ckpt_path,
#       7         "file": Path(ckpt_path).name,
#    (...)
#      12         "config": cfg
#      13     }
#
# KeyError: 'config'

# %%
METRICS_OF_INTEREST = [
    "mPQ/Validation",
    "epithelial-PQ/Validation",
    "lymphocyte-PQ/Validation",
    "macrophage-PQ/Validation",
    "neutrophil-PQ/Validation",
    "bPQ/Validation",
]

df_2 = compare_checkpoints(
    configs=checkpoint_configs,
    metrics=METRICS_OF_INTEREST,
    show_best_epoch=False,
    float_precision=3,
)
manual_rows = [
    {
        "name": "SamH-Rosie-LoRA-r8-256",
        "patch_size": 256,
        "best_metric(IoU)": 0.683,           
        "mPQ/Validation": 0.570,             
        "epithelial-PQ/Validation": 0.585,
        "lymphocyte-PQ/Validation": 0.559,
        "macrophage-PQ/Validation": 0.378,
        "neutrophil-PQ/Validation": 0.441,
        "bPQ/Validation": 0.625,            
    },
    {
        "name": "SamH-Rosie-LoRA-r16-256",
        "patch_size": 256,
        "best_metric(IoU)": 0.675,
        "mPQ/Validation": 0.568,
        "epithelial-PQ/Validation": 0.585,
        "lymphocyte-PQ/Validation": 0.562,
        "macrophage-PQ/Validation": 0.366,
        "neutrophil-PQ/Validation": 0.448,
        "bPQ/Validation": 0.620,
    }
]
df_lora = pd.DataFrame(manual_rows)
df_2 = pd.concat([df_2, df_lora], ignore_index=True)

df_2
# Out:
#                      name  patch_size  best_metric(IoU)  mPQ/Validation  \
# 0                SamH-256         256             0.621           0.562
# 1     SamH-Rosie-FiLM-256         256             0.688           0.602
# 2             Virchow-256         256             0.664           0.586
# 3  Virchow-Rosie-FiLM-256         256             0.664           0.586
# 4                SamH-128         128             0.621           0.562
# 5     SamH-Rosie-FiLM-128         128             0.618           0.555
#
#    epithelial-PQ/Validation  lymphocyte-PQ/Validation  \
# 0                     0.588                     0.521
# 1                     0.655                     0.535
# 2                     0.634                     0.517
# 3                     0.631                     0.475
# 4                     0.588                     0.521
# 5                     0.580                     0.536
#
#    macrophage-PQ/Validation  neutrophil-PQ/Validation  bPQ/Validation
# 0                     0.381                     0.475           0.616
# 1                     0.424                     0.421           0.683
# 2                     0.368                     0.452           0.656
# 3                     0.417                     0.486           0.658
# 4                     0.381                     0.475           0.616
# 5                     0.377                     0.415           0.613

# %% [markdown]
# ## Save df as pickle

# %%
from pathlib import Path

comparison_dir = Path("../comparison_dfs")
comparison_dir.mkdir(exist_ok=True)

# %%
def save_comparison_df(df, name, folder=comparison_dir):
    """
    Saves comparison dataframe as a pickle file.
    Args:
        df (pd.DataFrame): The comparison table.
        name (str): File name without extension.
    """
    path = Path(folder) / f"{name}.pkl"
    df.to_pickle(path)
    print(f"Saved comparison df to {path}")

# %%
df_name = "film_vs_cellvit"
save_comparison_df(df, df_name)
# Out:
# Saved comparison df to ../comparison_dfs/film_vs_cellvit.pkl

# %% [markdown]
# ## Read saved df

# %%
def load_comparison_df(name, folder=comparison_dir):
    """
    Loads a saved comparison dataframe from pickle.
    """
    path = Path(folder) / f"{name}.pkl"
    df = pd.read_pickle(path)
    print(f"📄 Loaded df from {path}")
    return df

# %%
df_loaded = load_comparison_df("film_vs_cellvit")
df_loaded
# Out:
# 📄 Loaded df from ../comparison_dfs/film_vs_cellvit.pkl
#           name      checkpoint  patch_size  best_metric(IoU)  \
# 0     FiLM-256  model_best.pth         256             0.688
# 1     FiLM-128  model_best.pth         128             0.618
# 2  CellViT-128  model_best.pth         128             0.621
#
#    Binary-Cell-Dice-Mean/Validation  Binary-Cell-Jacard-Mean/Validation  \
# 0                             0.819                               0.709
# 1                             0.787                               0.678
# 2                             0.786                               0.675
#
#    mPQ/Validation  epithelial-PQ/Validation  lymphocyte-PQ/Validation  \
# 0           0.602                     0.655                     0.535
# 1           0.555                     0.580                     0.536
# 2           0.562                     0.588                     0.521
#
#    macrophage-PQ/Validation  neutrophil-PQ/Validation  bPQ/Validation  \
# 0                     0.424                     0.421           0.683
# 1                     0.377                     0.415           0.613
# 2                     0.381                     0.475           0.616
#
#    hv_map_mse/Validation  hv_map_msge/Validation
# 0                  0.024                   0.207
# 1                  0.027                   0.223
# 2                  0.029                   0.220

# %% [markdown]
# ## Merge dfs

# %%
def merge_comparison_dfs(df_list, how="outer"):
    """
    Merge a list of comparison dataframes row-wise.
    Args:
        df_list (list[pd.DataFrame])
        how (str): 'outer' or 'inner'
    """
    merged = pd.concat(df_list, axis=0, join=how, ignore_index=True)
    print(f"Merged {len(df_list)} dataframes")
    return merged

# %%
#Example
df1 = load_comparison_df("film_vs_cellvit")
#df2 = load_comparison_df("cellvit_p256_baseline")

df_list = [df1]

merged_df = merge_comparison_dfs(df_list)
merged_df

#To save, give a name
df_name = "film_vs_cellvit_2"
save_comparison_df(merged_df, df_name)
# Out:
# 📄 Loaded df from ../comparison_dfs/film_vs_cellvit.pkl
# Merged 1 dataframes
# Saved comparison df to ../comparison_dfs/film_vs_cellvit_2.pkl
